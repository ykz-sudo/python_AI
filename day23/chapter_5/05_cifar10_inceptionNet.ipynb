# %%
# 导入必要的库
import matplotlib as mpl
import matplotlib.pyplot as plt
# 在Jupyter notebook中内联显示图表
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
from tqdm.auto import tqdm  # 进度条库
import torch
import torch.nn as nn
import torch.nn.functional as F

# 打印Python版本信息
print(sys.version_info)

# 打印各个库的版本信息
for module in mpl, np, pd, sklearn, torch:
    print(module.__name__, module.__version__)

# 设置设备：如果有GPU则使用GPU，否则使用CPU
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)
# Out:
# sys.version_info(major=3, minor=12, micro=3, releaselevel='final', serial=0)
# matplotlib 3.10.0
# numpy 1.26.4
# pandas 2.2.3
# sklearn 1.6.0
# torch 2.7.1+cpu
# cpu

# %% [markdown]
# # 数据预处理

# %%
from pathlib import Path

DATA_DIR = Path("D:/cifar-10")

train_lables_file = DATA_DIR / "trainLabels.csv"
test_csv_file = DATA_DIR / "sampleSubmission.csv" #测试集模板csv文件
train_folder = DATA_DIR / "train/train"
test_folder = DATA_DIR / "test/test"


#所有的类别
class_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck',
]
# INSERT_YOUR_CODE
import pandas as pd

def load_image_paths_and_labels(labels_csv_path, images_folder):
    """
    读取labels_csv_path（trainLabels.csv），为每张图片拼接完整路径，并返回[(img_path, label), ...]的列表
    """
    df = pd.read_csv(labels_csv_path)
    items = []
    for idx, row in df.iterrows():
        img_name = row['id']  # 假设csv第一列是id（去掉.jpg后缀的文件名）
        label = row['label']
        img_path = images_folder / f"{img_name}.png"  # cifar10可能是png，也可能是jpg，请确保格式一致
        if not img_path.exists():
            img_path = images_folder / f"{img_name}.jpg"
        items.append( (str(img_path), label) )
    return items

# 示例调用方法
train_items = load_image_paths_and_labels(train_lables_file, train_folder)
# test_items = load_image_paths_and_labels(test_csv_file, test_folder)

import pprint
pprint.pprint(train_items[:5])
# Out:
# [('D:\\cifar-10\\train\\train\\1.png', 'frog'),
#  ('D:\\cifar-10\\train\\train\\2.png', 'truck'),
#  ('D:\\cifar-10\\train\\train\\3.png', 'truck'),
#  ('D:\\cifar-10\\train\\train\\4.png', 'deer'),
#  ('D:\\cifar-10\\train\\train\\5.png', 'automobile')]

# %%
# INSERT_YOUR_CODE
import pandas as pd

# 将train_items分为45000条用于训练，5000条用于验证
train_items_ = train_items[:45000]
valid_items_ = train_items[45000:]

# 转为DataFrame
train_df = pd.DataFrame(train_items_, columns=["img_path", "label"])
valid_df = pd.DataFrame(valid_items_, columns=["img_path", "label"])
# test_df = pd.DataFrame(test_items, columns=["img_path", "label"])

# %%
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

class Cifar10Dataset(Dataset):
    df_map = {
        "train": train_df,
        "eval": valid_df,
    }
    label_to_idx = {label: idx for idx, label in enumerate(class_names)} # 类别映射为idx
    idx_to_label = {idx: label for idx, label in enumerate(class_names)} # idx映射为类别,为了test使用
    def __init__(self, mode, transform=None):
        self.df = self.df_map.get(mode, None) # 获取对应模式的df，不同字符串对应不同模式
        if self.df is None:
            raise ValueError("mode should be one of train, val, test, but got {}".format(mode))
        # assert self.df, "df is None"
        self.transform = transform

    def __getitem__(self, index):
        img_path, label = self.df.iloc[index] # 获取图片路径和标签
        img = Image.open(img_path).convert('RGB')
        # # img 转换为 channel first
        # img = img.transpose((2, 0, 1))
        # transform
        img = self.transform(img) # 数据增强
        # label 转换为 idx
        label = self.label_to_idx[label]
        return img, label

    def __len__(self):
        return self.df.shape[0] # 返回df的行数,样本数

IMAGE_SIZE = 32
mean, std = [0.4914, 0.4822, 0.4465], [0.247, 0.243, 0.261]

transforms_train = transforms.Compose([
        # resize
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)), #缩放
        # random rotation 40
        transforms.RandomRotation(40), #随机旋转
        # horizaontal flip
        transforms.RandomHorizontalFlip(),  #随机水平翻转
        transforms.ToTensor(), #转换为tensor
        transforms.Normalize(mean, std) #标准化
    ]) #数据增强

transforms_eval = transforms.Compose([
        # resize
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
# ToTensor还将图像的维度从[height, width, channels]转换为[channels, height, width]。
train_ds = Cifar10Dataset("train", transforms_train)
eval_ds = Cifar10Dataset("eval", transforms_eval)

# %%
# 对train_ds计算均值和标准差
# from torch.utils.data import DataLoader
# import torch
#
# loader = DataLoader(train_ds, batch_size=64, shuffle=False, num_workers=2)
#
# mean = torch.zeros(3)
# std = torch.zeros(3)
# n_pixels = 0
#
# for images, _ in loader:  # images: [B, 3, H, W]
#     batch_pixels = images.shape[0] * images.shape[2] * images.shape[3]
#     mean += images.sum([0, 2, 3])
#     std += (images ** 2).sum([0, 2, 3])
#     n_pixels += batch_pixels
#
# mean /= n_pixels
# std = torch.sqrt(std / n_pixels - mean ** 2)
#
# print("train_ds按通道均值:", mean)
# print("train_ds按通道标准差:", std)

# %%
from torch.utils.data import DataLoader

# 创建训练集和验证集的DataLoader
batch_size = 32

train_loader = DataLoader(
    train_ds,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据
)

test_loader = DataLoader(
    eval_ds,
    batch_size=batch_size,
    shuffle=False,  # 测试时不需要打乱
)

print(f"训练集DataLoader批次数: {len(train_loader)}")
print(f"测试集DataLoader批次数: {len(test_loader)}")
print(f"每个批次大小: {batch_size}")

# 查看一个批次的数据
for batch_images, batch_labels in train_loader:
    print(f"批次图像张量形状: {batch_images.shape}")
    print(f"批次标签张量形状: {batch_labels.shape}")
    print(batch_labels)
    break
# Out:
# 训练集DataLoader批次数: 1407
# 测试集DataLoader批次数: 157
# 每个批次大小: 32
# 批次图像张量形状: torch.Size([32, 3, 32, 32])
# 批次标签张量形状: torch.Size([32])
# tensor([8, 2, 0, 0, 3, 7, 4, 9, 4, 7, 6, 0, 9, 4, 7, 4, 1, 2, 0, 6, 5, 8, 8, 7,
#         4, 1, 7, 0, 6, 9, 3, 6])

# %% [markdown]
# # 搭建模型

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# 定义InceptionBlock，模拟GoogleNet中的Inception结构
class InceptionBlock(nn.Module):
    def __init__(
        self, 
        in_channels,   # 输入特征图的通道数
        n1x1,          # 1x1卷积分支输出通道数
        n3x3red,       # 3x3卷积分支，先做1x1降维，降维后输出通道数
        n3x3,          # 3x3卷积分支，3x3卷积后输出通道数
        n5x5red,       # 5x5卷积分支，先做1x1降维，降维后输出通道数
        n5x5,          # 5x5卷积分支，5x5卷积后输出通道数
        pool_proj      # 池化+1x1卷积分支中，1x1卷积输出通道数
    ):
        super(InceptionBlock, self).__init__()
        # 第一分支：单独的1x1卷积，用于提取简单特征，增强非线性
        self.branch1 = nn.Conv2d(in_channels, n1x1, kernel_size=1)
        
        # 第二分支：1x1卷积降维后接3x3卷积
        self.branch2_1 = nn.Conv2d(in_channels, n3x3red, kernel_size=1)
        self.branch2_2 = nn.Conv2d(n3x3red, n3x3, kernel_size=3, padding=1)  # padding=1 保证尺寸不变
        
        # 第三分支：1x1卷积降维后接5x5卷积
        self.branch3_1 = nn.Conv2d(in_channels, n5x5red, kernel_size=1)
        self.branch3_2 = nn.Conv2d(n5x5red, n5x5, kernel_size=5, padding=2)  # padding=2 保证尺寸不变
        
        # 第四分支：3x3最大池化后，再接1x1卷积(用于压缩通道数)
        self.branch4_pool = nn.MaxPool2d(kernel_size=3, stride=1, padding=1) # 池化不会改变尺寸
        self.branch4_conv = nn.Conv2d(in_channels, pool_proj, kernel_size=1)

    def forward(self, x):
        # 第一分支的前向传播：1x1卷积 + ReLU
        branch1 = F.relu(self.branch1(x), inplace=True)

        # 第二分支：1x1卷积 + ReLU -> 3x3卷积 + ReLU
        branch2 = F.relu(self.branch2_1(x), inplace=True)
        branch2 = F.relu(self.branch2_2(branch2), inplace=True)
        
        # 第三分支：1x1卷积 + ReLU -> 5x5卷积 + ReLU
        branch3 = F.relu(self.branch3_1(x), inplace=True)
        branch3 = F.relu(self.branch3_2(branch3), inplace=True)
        
        # 第四分支：3x3最大池化 -> 1x1卷积 + ReLU
        branch4 = self.branch4_pool(x)
        branch4 = F.relu(self.branch4_conv(branch4), inplace=True)
        
        # 将四个分支在通道维度上拼接，得到本block的输出
        outputs = [branch1, branch2, branch3, branch4]
        # 这里 outputs 列表包含了4个分支的输出 (1x1卷积、3x3卷积路径、5x5卷积路径、池化路径)，
        # 每个分支输出 shape 为 [batch_size, 指定分支通道数, 高, 宽]。
        # 后面通过 torch.cat(outputs, 1) 这个操作，将这些不同分支在“通道”维度拼接起来，形成 Inception block 的输出。
        # 这样做能融合多尺度的特征，提高模型的表达能力。
        return torch.cat(outputs, 1)  # 通道方向cat

# 定义InceptionNet整体结构
class InceptionNet(nn.Module):
    def __init__(self, num_classes=10):
        super(InceptionNet, self).__init__()
        # ======= 第一阶段 =======
        # 初始卷积层：输入3通道（RGB），输出64通道，卷积核3x3，保持输入输出width/height一致
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(64)                # 批归一化，加速收敛
        self.relu = nn.ReLU(inplace=True)
        self.maxpool = nn.MaxPool2d(2, 2)            # 降采样，将空间尺寸减半（32->16）
        
        # ======= 第二阶段 =======
        # 第一个Inception模块：输入64通道，输出32+64+16+16=128通道
        self.inception1 = InceptionBlock(64, 32, 48, 64, 8, 16, 16)
        # 第一阶段后再一次最大池化，降采样（16->8）
        self.maxpool1 = nn.MaxPool2d(2, 2)
        
        # 第二个Inception模块：输入128通道，输出64+64+16+16=160通道
        self.inception2 = InceptionBlock(128, 64, 48, 64, 8, 16, 16)
        # 第二阶段后最大池化（8->4）
        self.maxpool2 = nn.MaxPool2d(2, 2)
        # 如果需要，可以用下方注释的参数进行更深结构的测试：
        # InceptionBlock(64, 64, 96, 128, 16, 32, 32) # 输出256通道
        # InceptionBlock(256, 128, 128, 192, 32, 96, 64) # 输出480通道

        # ======= 分类器部分 =======
        # 使用Dropout防止过拟合
        self.dropout = nn.Dropout(0.4)
        # 全连接层：输入展平后160*4*4，输出为类别数
        # 160为前一层输出通道，4*4是特征图的空间尺寸
        self.fc = nn.Linear(160*4*4, num_classes)

    def forward(self, x):
        # 前向传播流程
        x = self.conv1(x)            # 卷积
        x = self.bn1(x)              # 批归一化
        x = self.relu(x)             # 激活
        x = self.maxpool(x)          # 第一次池化（32->16）

        x = self.inception1(x)       # 第一个inception block
        x = self.maxpool1(x)         # 第二次池化（16->8）

        x = self.inception2(x)       # 第二个inception block
        x = self.maxpool2(x)         # 第三次池化（8->4）

        # self.avgpool = nn.AdaptiveAvgPool2d((1, 1)) 已移除，使用直接展平
        x = torch.flatten(x, 1)      # 展平成二维 (batch_size, 特征数)
        x = self.dropout(x)          # Dropout
        x = self.fc(x)               # 全连接输出分类结果
        return x
        
# 实例化InceptionNet，设置分类类别数（默认10类：CIFAR-10）
model = InceptionNet(num_classes=10)

# %%
# 使用随机输入对模型进行一次前向计算以验证模型结构是否正确
import torch

dummy_input = torch.randn(32, 3, 32, 32)
output = model(dummy_input) #前向传播/前向计算/正向传播
print(f"Output shape: {output.shape}")
# Out:
# Output shape: torch.Size([32, 10])

# %%
# 输出model每一层的参数量
total_params = 0  # 初始化总参数量为0
print("各层参数量统计：")  # 打印参数统计表头
for name, param in model.named_parameters():  # 遍历模型中所有需要优化的参数
    if param.requires_grad:  # 只有需要梯度更新的参数才统计
        num_params = param.numel()  # 计算当前参数的元素总数
        total_params += num_params  # 更新总参数量
        print(f"{name}: {num_params}")  # 输出当前层的参数量
print(f"模型总参数量: {total_params}")  # 输出模型总参数量
# Out:
# 各层参数量统计：
# conv1.weight: 1728
# conv1.bias: 64
# bn1.weight: 64
# bn1.bias: 64
# inception1.branch1.weight: 2048
# inception1.branch1.bias: 32
# inception1.branch2_1.weight: 3072
# inception1.branch2_1.bias: 48
# inception1.branch2_2.weight: 27648
# inception1.branch2_2.bias: 64
# inception1.branch3_1.weight: 512
# inception1.branch3_1.bias: 8
# inception1.branch3_2.weight: 3200
# inception1.branch3_2.bias: 16
# inception1.branch4_conv.weight: 1024
# inception1.branch4_conv.bias: 16
# inception2.branch1.weight: 8192
# inception2.branch1.bias: 64
# inception2.branch2_1.weight: 6144
# inception2.branch2_1.bias: 48
# inception2.branch2_2.weight: 27648
# inception2.branch2_2.bias: 64
# inception2.branch3_1.weight: 1024
# inception2.branch3_1.bias: 8
# inception2.branch3_2.weight: 3200
# inception2.branch3_2.bias: 16
# inception2.branch4_conv.weight: 2048
# inception2.branch4_conv.bias: 16
# fc.weight: 25600
# fc.bias: 10
# 模型总参数量: 113690

# %% [markdown]
# # 训练

# %%
import torch.nn as nn
import torch.optim as optim

# 初始化交叉熵损失函数，内部会做softmax
criterion = nn.CrossEntropyLoss()

# 初始化优化器（这里选用Adam，也可以使用SGD等）
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import wangdao_train
# 假设train_loader和val_loader已定义，device已经设为"cuda"或"cpu"
trainer = wangdao_train.Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    eval_step=100
)

# 设定训练轮数
num_epochs = 20

# 开始训练
trainer.train(num_epochs)
# Out:
# [Step 100] Val Loss: 1.8913 Val Acc: 0.3254
# [Step 200] Val Loss: 1.6166 Val Acc: 0.4180
# [Step 300] Val Loss: 1.5419 Val Acc: 0.4352
# [Step 400] Val Loss: 1.4877 Val Acc: 0.4512
# [Step 500] Val Loss: 1.4120 Val Acc: 0.4826
# [Step 600] Val Loss: 1.3369 Val Acc: 0.5152
# [Step 700] Val Loss: 1.3744 Val Acc: 0.4912
# [Step 800] Val Loss: 1.3118 Val Acc: 0.5324
# [Step 900] Val Loss: 1.2620 Val Acc: 0.5514
# [Step 1000] Val Loss: 1.2621 Val Acc: 0.5428
# [Step 1100] Val Loss: 1.2771 Val Acc: 0.5452
# [Step 1200] Val Loss: 1.2297 Val Acc: 0.5624
# [Step 1300] Val Loss: 1.2871 Val Acc: 0.5336
# [Step 1400] Val Loss: 1.1822 Val Acc: 0.5854
# Epoch [1/20]  Train Loss: 1.4935  Train Acc: 0.4617
# [Step 1500] Val Loss: 1.1554 Val Acc: 0.5828
# [Step 1600] Val Loss: 1.1430 Val Acc: 0.5988
# [Step 1700] Val Loss: 1.1316 Val Acc: 0.6058
# [Step 1800] Val Loss: 1.1597 Val Acc: 0.5884
# [Step 1900] Val Loss: 1.1015 Val Acc: 0.6134
# [Step 2000] Val Loss: 1.1319 Val Acc: 0.6024
# [Step 2100] Val Loss: 1.0875 Val Acc: 0.6166
# [Step 2200] Val Loss: 1.0863 Val Acc: 0.6156
# [Step 2300] Val Loss: 1.0501 Val Acc: 0.6260
# [Step 2400] Val Loss: 1.0771 Val Acc: 0.6194
# [Step 2500] Val Loss: 1.0695 Val Acc: 0.6186
# [Step 2600] Val Loss: 1.0410 Val Acc: 0.6364
# [Step 2700] Val Loss: 1.0512 Val Acc: 0.6288
# [Step 2800] Val Loss: 1.0227 Val Acc: 0.6412
# Epoch [2/20]  Train Loss: 1.2004  Train Acc: 0.5738
# [Step 2900] Val Loss: 1.0458 Val Acc: 0.6322
# [Step 3000] Val Loss: 0.9817 Val Acc: 0.6508
# [Step 3100] Val Loss: 0.9986 Val Acc: 0.6470
# [Step 3200] Val Loss: 1.0012 Val Acc: 0.6498
# [Step 3300] Val Loss: 0.9763 Val Acc: 0.6574
# [Step 3400] Val Loss: 0.9842 Val Acc: 0.6568
# [Step 3500] Val Loss: 0.9463 Val Acc: 0.6728
# [Step 3600] Val Loss: 0.9580 Val Acc: 0.6648
# [Step 3700] Val Loss: 0.9873 Val Acc: 0.6512
# [Step 3800] Val Loss: 0.9588 Val Acc: 0.6658
# [Step 3900] Val Loss: 0.9346 Val Acc: 0.6762
# [Step 4000] Val Loss: 0.9607 Val Acc: 0.6710
# [Step 4100] Val Loss: 0.9505 Val Acc: 0.6724
# [Step 4200] Val Loss: 0.9306 Val Acc: 0.6722
# Epoch [3/20]  Train Loss: 1.0828  Train Acc: 0.6171
# [Step 4300] Val Loss: 0.9396 Val Acc: 0.6754
# [Step 4400] Val Loss: 0.9647 Val Acc: 0.6674
# [Step 4500] Val Loss: 0.9328 Val Acc: 0.6794
# [Step 4600] Val Loss: 0.9565 Val Acc: 0.6656
# [Step 4700] Val Loss: 0.9749 Val Acc: 0.6578
# [Step 4800] Val Loss: 0.9271 Val Acc: 0.6758
# [Step 4900] Val Loss: 0.9190 Val Acc: 0.6856
# [Step 5000] Val Loss: 0.8907 Val Acc: 0.6902
# [Step 5100] Val Loss: 0.9079 Val Acc: 0.6784
# [Step 5200] Val Loss: 0.9043 Val Acc: 0.6876
# [Step 5300] Val Loss: 0.8887 Val Acc: 0.6912
# [Step 5400] Val Loss: 0.8794 Val Acc: 0.6974
# [Step 5500] Val Loss: 0.9193 Val Acc: 0.6780
# [Step 5600] Val Loss: 0.9212 Val Acc: 0.6764
# Epoch [4/20]  Train Loss: 1.0132  Train Acc: 0.6412
# [Step 5700] Val Loss: 0.8907 Val Acc: 0.6964
# [Step 5800] Val Loss: 0.9242 Val Acc: 0.6788
# [Step 5900] Val Loss: 0.8675 Val Acc: 0.6980
# [Step 6000] Val Loss: 0.8583 Val Acc: 0.7042
# [Step 6100] Val Loss: 0.8635 Val Acc: 0.7036
# [Step 6200] Val Loss: 0.8830 Val Acc: 0.6920
# [Step 6300] Val Loss: 0.8595 Val Acc: 0.7068
# [Step 6400] Val Loss: 0.8478 Val Acc: 0.7098
# [Step 6500] Val Loss: 0.8617 Val Acc: 0.7074
# [Step 6600] Val Loss: 0.8488 Val Acc: 0.7120
# [Step 6700] Val Loss: 0.8698 Val Acc: 0.7024
# [Step 6800] Val Loss: 0.9121 Val Acc: 0.6836
# [Step 6900] Val Loss: 0.8714 Val Acc: 0.7024
# [Step 7000] Val Loss: 0.8584 Val Acc: 0.7046
# Epoch [5/20]  Train Loss: 0.9659  Train Acc: 0.6593
# [Step 7100] Val Loss: 0.8668 Val Acc: 0.7014
# [Step 7200] Val Loss: 0.8362 Val Acc: 0.7118
# [Step 7300] Val Loss: 0.8326 Val Acc: 0.7132
# [Step 7400] Val Loss: 0.9118 Val Acc: 0.6806
# [Step 7500] Val Loss: 0.8453 Val Acc: 0.7126
# [Step 7600] Val Loss: 0.8340 Val Acc: 0.7092
# [Step 7700] Val Loss: 0.8508 Val Acc: 0.7090
# [Step 7800] Val Loss: 0.8542 Val Acc: 0.7060
# [Step 7900] Val Loss: 0.8378 Val Acc: 0.7120
# [Step 8000] Val Loss: 0.8287 Val Acc: 0.7120
# [Step 8100] Val Loss: 0.8485 Val Acc: 0.7076
# [Step 8200] Val Loss: 0.8212 Val Acc: 0.7128
# [Step 8300] Val Loss: 0.8543 Val Acc: 0.7064
# [Step 8400] Val Loss: 0.8153 Val Acc: 0.7180
# Epoch [6/20]  Train Loss: 0.9288  Train Acc: 0.6714
# [Step 8500] Val Loss: 0.8524 Val Acc: 0.7060
# [Step 8600] Val Loss: 0.8096 Val Acc: 0.7224
# [Step 8700] Val Loss: 0.8128 Val Acc: 0.7226
# [Step 8800] Val Loss: 0.8092 Val Acc: 0.7204
# [Step 8900] Val Loss: 0.8216 Val Acc: 0.7152
# [Step 9000] Val Loss: 0.8029 Val Acc: 0.7214
# [Step 9100] Val Loss: 0.8276 Val Acc: 0.7114
# [Step 9200] Val Loss: 0.8221 Val Acc: 0.7162
# [Step 9300] Val Loss: 0.8900 Val Acc: 0.6894
# [Step 9400] Val Loss: 0.7979 Val Acc: 0.7210
# [Step 9500] Val Loss: 0.8156 Val Acc: 0.7194
# [Step 9600] Val Loss: 0.8308 Val Acc: 0.7210
# [Step 9700] Val Loss: 0.8324 Val Acc: 0.7112
# [Step 9800] Val Loss: 0.8058 Val Acc: 0.7222
# Epoch [7/20]  Train Loss: 0.9047  Train Acc: 0.6836
# [Step 9900] Val Loss: 0.8103 Val Acc: 0.7190
# [Step 10000] Val Loss: 0.7982 Val Acc: 0.7300
# [Step 10100] Val Loss: 0.7999 Val Acc: 0.7260
# [Step 10200] Val Loss: 0.8030 Val Acc: 0.7274
# [Step 10300] Val Loss: 0.8125 Val Acc: 0.7138
# [Step 10400] Val Loss: 0.7869 Val Acc: 0.7284
# [Step 10500] Val Loss: 0.7941 Val Acc: 0.7228
# [Step 10600] Val Loss: 0.7766 Val Acc: 0.7300
# [Step 10700] Val Loss: 0.8082 Val Acc: 0.7170
# [Step 10800] Val Loss: 0.8102 Val Acc: 0.7206
# [Step 10900] Val Loss: 0.8235 Val Acc: 0.7176
# [Step 11000] Val Loss: 0.8369 Val Acc: 0.7030
# [Step 11100] Val Loss: 0.8074 Val Acc: 0.7180
# [Step 11200] Val Loss: 0.8522 Val Acc: 0.7108
# Epoch [8/20]  Train Loss: 0.8725  Train Acc: 0.6934
# [Step 11300] Val Loss: 0.8055 Val Acc: 0.7196
# [Step 11400] Val Loss: 0.8255 Val Acc: 0.7164
# [Step 11500] Val Loss: 0.7750 Val Acc: 0.7352
# [Step 11600] Val Loss: 0.7982 Val Acc: 0.7276
# [Step 11700] Val Loss: 0.7918 Val Acc: 0.7228
# [Step 11800] Val Loss: 0.7603 Val Acc: 0.7386
# [Step 11900] Val Loss: 0.7864 Val Acc: 0.7250
# [Step 12000] Val Loss: 0.7837 Val Acc: 0.7368
# [Step 12100] Val Loss: 0.8298 Val Acc: 0.7214
# [Step 12200] Val Loss: 0.7607 Val Acc: 0.7468
# [Step 12300] Val Loss: 0.7803 Val Acc: 0.7282
# [Step 12400] Val Loss: 0.7989 Val Acc: 0.7210
# [Step 12500] Val Loss: 0.7684 Val Acc: 0.7384
# [Step 12600] Val Loss: 0.7808 Val Acc: 0.7330
# Epoch [9/20]  Train Loss: 0.8545  Train Acc: 0.7002
# [Step 12700] Val Loss: 0.7746 Val Acc: 0.7302
# [Step 12800] Val Loss: 0.7537 Val Acc: 0.7374
# [Step 12900] Val Loss: 0.8025 Val Acc: 0.7260
# [Step 13000] Val Loss: 0.7807 Val Acc: 0.7326
# [Step 13100] Val Loss: 0.7921 Val Acc: 0.7204
# [Step 13200] Val Loss: 0.7635 Val Acc: 0.7398
# [Step 13300] Val Loss: 0.7941 Val Acc: 0.7258
# [Step 13400] Val Loss: 0.7827 Val Acc: 0.7308
# [Step 13500] Val Loss: 0.7979 Val Acc: 0.7294
# [Step 13600] Val Loss: 0.7507 Val Acc: 0.7422
# [Step 13700] Val Loss: 0.7722 Val Acc: 0.7340
# [Step 13800] Val Loss: 0.7415 Val Acc: 0.7402
# [Step 13900] Val Loss: 0.7666 Val Acc: 0.7390
# [Step 14000] Val Loss: 0.7835 Val Acc: 0.7280
# Epoch [10/20]  Train Loss: 0.8331  Train Acc: 0.7059
# [Step 14100] Val Loss: 0.7876 Val Acc: 0.7206
# [Step 14200] Val Loss: 0.7644 Val Acc: 0.7292
# [Step 14300] Val Loss: 0.7554 Val Acc: 0.7368
# [Step 14400] Val Loss: 0.7331 Val Acc: 0.7482
# [Step 14500] Val Loss: 0.7771 Val Acc: 0.7298
# [Step 14600] Val Loss: 0.7747 Val Acc: 0.7290
# [Step 14700] Val Loss: 0.7536 Val Acc: 0.7446
# [Step 14800] Val Loss: 0.7632 Val Acc: 0.7386
# [Step 14900] Val Loss: 0.7590 Val Acc: 0.7396
# [Step 15000] Val Loss: 0.7655 Val Acc: 0.7338
# [Step 15100] Val Loss: 0.7498 Val Acc: 0.7480
# [Step 15200] Val Loss: 0.7573 Val Acc: 0.7442
# [Step 15300] Val Loss: 0.7479 Val Acc: 0.7420
# [Step 15400] Val Loss: 0.7494 Val Acc: 0.7390
# Epoch [11/20]  Train Loss: 0.8173  Train Acc: 0.7134
# [Step 15500] Val Loss: 0.7662 Val Acc: 0.7388
# [Step 15600] Val Loss: 0.7444 Val Acc: 0.7446
# [Step 15700] Val Loss: 0.7636 Val Acc: 0.7326
# [Step 15800] Val Loss: 0.7494 Val Acc: 0.7484
# [Step 15900] Val Loss: 0.7419 Val Acc: 0.7386
# [Step 16000] Val Loss: 0.7397 Val Acc: 0.7414
# [Step 16100] Val Loss: 0.7547 Val Acc: 0.7426
# [Step 16200] Val Loss: 0.7437 Val Acc: 0.7444
# [Step 16300] Val Loss: 0.7259 Val Acc: 0.7504
# [Step 16400] Val Loss: 0.7317 Val Acc: 0.7412
# [Step 16500] Val Loss: 0.7249 Val Acc: 0.7512
# [Step 16600] Val Loss: 0.7489 Val Acc: 0.7426
# [Step 16700] Val Loss: 0.7213 Val Acc: 0.7496
# [Step 16800] Val Loss: 0.7196 Val Acc: 0.7524
# Epoch [12/20]  Train Loss: 0.7976  Train Acc: 0.7208
# [Step 16900] Val Loss: 0.7745 Val Acc: 0.7282
# [Step 17000] Val Loss: 0.7172 Val Acc: 0.7544
# [Step 17100] Val Loss: 0.7518 Val Acc: 0.7408
# [Step 17200] Val Loss: 0.7560 Val Acc: 0.7458
# [Step 17300] Val Loss: 0.7419 Val Acc: 0.7514
# [Step 17400] Val Loss: 0.7260 Val Acc: 0.7568
# [Step 17500] Val Loss: 0.7331 Val Acc: 0.7518
# [Step 17600] Val Loss: 0.7470 Val Acc: 0.7436
# [Step 17700] Val Loss: 0.7464 Val Acc: 0.7426
# [Step 17800] Val Loss: 0.7715 Val Acc: 0.7376
# [Step 17900] Val Loss: 0.7380 Val Acc: 0.7502
# [Step 18000] Val Loss: 0.7492 Val Acc: 0.7410
# [Step 18100] Val Loss: 0.7029 Val Acc: 0.7496
# [Step 18200] Val Loss: 0.7203 Val Acc: 0.7472
# Epoch [13/20]  Train Loss: 0.7914  Train Acc: 0.7216
# [Step 18300] Val Loss: 0.7801 Val Acc: 0.7324
# [Step 18400] Val Loss: 0.7303 Val Acc: 0.7462
# [Step 18500] Val Loss: 0.7576 Val Acc: 0.7352
# [Step 18600] Val Loss: 0.7751 Val Acc: 0.7386
# [Step 18700] Val Loss: 0.7144 Val Acc: 0.7584
# [Step 18800] Val Loss: 0.7356 Val Acc: 0.7480
# [Step 18900] Val Loss: 0.7705 Val Acc: 0.7384
# [Step 19000] Val Loss: 0.7389 Val Acc: 0.7480
# [Step 19100] Val Loss: 0.7413 Val Acc: 0.7492
# [Step 19200] Val Loss: 0.7247 Val Acc: 0.7464
# [Step 19300] Val Loss: 0.7580 Val Acc: 0.7446
# [Step 19400] Val Loss: 0.7408 Val Acc: 0.7452
# [Step 19500] Val Loss: 0.7293 Val Acc: 0.7560
# [Step 19600] Val Loss: 0.7471 Val Acc: 0.7460
# Epoch [14/20]  Train Loss: 0.7723  Train Acc: 0.7297
# [Step 19700] Val Loss: 0.7304 Val Acc: 0.7526
# [Step 19800] Val Loss: 0.7179 Val Acc: 0.7558
# [Step 19900] Val Loss: 0.7102 Val Acc: 0.7570
# [Step 20000] Val Loss: 0.7248 Val Acc: 0.7528
# [Step 20100] Val Loss: 0.7263 Val Acc: 0.7544
# [Step 20200] Val Loss: 0.7327 Val Acc: 0.7534
# [Step 20300] Val Loss: 0.7225 Val Acc: 0.7516
# [Step 20400] Val Loss: 0.6940 Val Acc: 0.7576
# [Step 20500] Val Loss: 0.7026 Val Acc: 0.7570
# [Step 20600] Val Loss: 0.7080 Val Acc: 0.7568
# [Step 20700] Val Loss: 0.7292 Val Acc: 0.7538
# [Step 20800] Val Loss: 0.7144 Val Acc: 0.7576
# [Step 20900] Val Loss: 0.7187 Val Acc: 0.7472
# [Step 21000] Val Loss: 0.7337 Val Acc: 0.7536
# [Step 21100] Val Loss: 0.7294 Val Acc: 0.7408
# Epoch [15/20]  Train Loss: 0.7624  Train Acc: 0.7353
# [Step 21200] Val Loss: 0.7289 Val Acc: 0.7472
# [Step 21300] Val Loss: 0.7048 Val Acc: 0.7490
# [Step 21400] Val Loss: 0.7074 Val Acc: 0.7582
# [Step 21500] Val Loss: 0.7120 Val Acc: 0.7552
# [Step 21600] Val Loss: 0.7106 Val Acc: 0.7560
# [Step 21700] Val Loss: 0.7276 Val Acc: 0.7452
# [Step 21800] Val Loss: 0.7099 Val Acc: 0.7576
# [Step 21900] Val Loss: 0.7068 Val Acc: 0.7568
# [Step 22000] Val Loss: 0.7062 Val Acc: 0.7616
# [Step 22100] Val Loss: 0.7321 Val Acc: 0.7500
# [Step 22200] Val Loss: 0.6979 Val Acc: 0.7608
# [Step 22300] Val Loss: 0.7018 Val Acc: 0.7596
# [Step 22400] Val Loss: 0.7042 Val Acc: 0.7570
# [Step 22500] Val Loss: 0.6857 Val Acc: 0.7654
# Epoch [16/20]  Train Loss: 0.7654  Train Acc: 0.7286
# [Step 22600] Val Loss: 0.7174 Val Acc: 0.7470
# [Step 22700] Val Loss: 0.6914 Val Acc: 0.7646
# [Step 22800] Val Loss: 0.6873 Val Acc: 0.7626
# [Step 22900] Val Loss: 0.7338 Val Acc: 0.7528
# [Step 23000] Val Loss: 0.6967 Val Acc: 0.7608
# [Step 23100] Val Loss: 0.6905 Val Acc: 0.7706
# [Step 23200] Val Loss: 0.6921 Val Acc: 0.7622
# [Step 23300] Val Loss: 0.6971 Val Acc: 0.7612
# [Step 23400] Val Loss: 0.7027 Val Acc: 0.7604
# [Step 23500] Val Loss: 0.6807 Val Acc: 0.7654
# [Step 23600] Val Loss: 0.6801 Val Acc: 0.7650
# [Step 23700] Val Loss: 0.6756 Val Acc: 0.7726
# [Step 23800] Val Loss: 0.6927 Val Acc: 0.7624
# [Step 23900] Val Loss: 0.6740 Val Acc: 0.7706
# Epoch [17/20]  Train Loss: 0.7547  Train Acc: 0.7368
# [Step 24000] Val Loss: 0.7242 Val Acc: 0.7466
# [Step 24100] Val Loss: 0.7228 Val Acc: 0.7498
# [Step 24200] Val Loss: 0.6767 Val Acc: 0.7672
# [Step 24300] Val Loss: 0.6762 Val Acc: 0.7686
# [Step 24400] Val Loss: 0.7104 Val Acc: 0.7594
# [Step 24500] Val Loss: 0.6924 Val Acc: 0.7604
# [Step 24600] Val Loss: 0.7105 Val Acc: 0.7598
# [Step 24700] Val Loss: 0.7095 Val Acc: 0.7564
# [Step 24800] Val Loss: 0.6910 Val Acc: 0.7668
# [Step 24900] Val Loss: 0.7016 Val Acc: 0.7666
# [Step 25000] Val Loss: 0.6906 Val Acc: 0.7620
# [Step 25100] Val Loss: 0.6936 Val Acc: 0.7648
# [Step 25200] Val Loss: 0.6797 Val Acc: 0.7700
# [Step 25300] Val Loss: 0.7382 Val Acc: 0.7514
# Epoch [18/20]  Train Loss: 0.7439  Train Acc: 0.7394
# [Step 25400] Val Loss: 0.7013 Val Acc: 0.7552
# [Step 25500] Val Loss: 0.6902 Val Acc: 0.7568
# [Step 25600] Val Loss: 0.6962 Val Acc: 0.7574
# [Step 25700] Val Loss: 0.7067 Val Acc: 0.7598
# [Step 25800] Val Loss: 0.7081 Val Acc: 0.7606
# [Step 25900] Val Loss: 0.6902 Val Acc: 0.7628
# [Step 26000] Val Loss: 0.6978 Val Acc: 0.7626
# [Step 26100] Val Loss: 0.7169 Val Acc: 0.7524
# [Step 26200] Val Loss: 0.7159 Val Acc: 0.7552
# [Step 26300] Val Loss: 0.6986 Val Acc: 0.7622
# [Step 26400] Val Loss: 0.7129 Val Acc: 0.7604
# [Step 26500] Val Loss: 0.7183 Val Acc: 0.7506
# [Step 26600] Val Loss: 0.6862 Val Acc: 0.7592
# [Step 26700] Val Loss: 0.6881 Val Acc: 0.7594
# Epoch [19/20]  Train Loss: 0.7394  Train Acc: 0.7390
# [Step 26800] Val Loss: 0.6873 Val Acc: 0.7654
# [Step 26900] Val Loss: 0.7467 Val Acc: 0.7432
# [Step 27000] Val Loss: 0.6951 Val Acc: 0.7596
# [Step 27100] Val Loss: 0.6975 Val Acc: 0.7648
# [Step 27200] Val Loss: 0.7017 Val Acc: 0.7560
# [Step 27300] Val Loss: 0.6861 Val Acc: 0.7676
# [Step 27400] Val Loss: 0.6697 Val Acc: 0.7700
# [Step 27500] Val Loss: 0.6975 Val Acc: 0.7558
# [Step 27600] Val Loss: 0.6957 Val Acc: 0.7620
# [Step 27700] Val Loss: 0.6812 Val Acc: 0.7592
# [Step 27800] Val Loss: 0.6832 Val Acc: 0.7648
# [Step 27900] Val Loss: 0.6937 Val Acc: 0.7614
# [Step 28000] Val Loss: 0.6923 Val Acc: 0.7626
# [Step 28100] Val Loss: 0.6804 Val Acc: 0.7604
# Epoch [20/20]  Train Loss: 0.7277  Train Acc: 0.7465

# %%
trainer.plot_curves()
