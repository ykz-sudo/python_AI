# %%
# 导入必要的库
import matplotlib as mpl
import matplotlib.pyplot as plt
# 在Jupyter notebook中内联显示图表
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
from tqdm.auto import tqdm  # 进度条库
import torch
import torch.nn as nn
import torch.nn.functional as F

# 打印Python版本信息
print(sys.version_info)

# 打印各个库的版本信息
for module in mpl, np, pd, sklearn, torch:
    print(module.__name__, module.__version__)

# 设置设备：如果有GPU则使用GPU，否则使用CPU
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)
# Out:
# sys.version_info(major=3, minor=12, micro=12, releaselevel='final', serial=0)
# matplotlib 3.10.0
# numpy 2.0.2
# pandas 2.2.2
# sklearn 1.6.1
# torch 2.9.0+cu126
# cuda:0

# %%
import json
token = {"username":"cskaoyan","key":"ff99d9d7ff71704e3e761217ceec03c5"}
with open('/content/kaggle.json', 'w') as file:
  json.dump(token, file)

# %%
# !cat /content/kaggle.json
# Out:
# {"username": "cskaoyan", "key": "ff99d9d7ff71704e3e761217ceec03c5"}

# %%
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle config set -n path -v /content
# Out:
# - path is now set to: /content

# %%
# !kaggle competitions download -c cifar-10
# Out:
# cifar-10.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/competitions/cifar-10/cifar-10.zip
# Out:
# Archive:  /content/competitions/cifar-10/cifar-10.zip
# replace sampleSubmission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test.7z? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace train.7z? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace trainLabels.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
# %pip install py7zr
# import py7zr
# a =py7zr.SevenZipFile(r'./train.7z','r')
# a.extractall(path=r'./competitions/cifar-10/')
# a.close()
# Out:
# Requirement already satisfied: py7zr in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: texttable in /usr/local/lib/python3.12/dist-packages (from py7zr) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from py7zr) (3.23.0)
# Requirement already satisfied: brotli>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from py7zr) (1.2.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from py7zr) (5.9.5)
# Requirement already satisfied: backports.zstd>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from py7zr) (1.3.0)
# Requirement already satisfied: pyppmd>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from py7zr) (1.3.1)
# Requirement already satisfied: pybcj>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from py7zr) (1.0.7)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from py7zr) (0.2.3)
# Requirement already satisfied: inflate64>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from py7zr) (1.0.4)

# %%
# !cp sampleSubmission.csv trainLabels.csv /content/competitions/cifar-10

# %%
# !ls /content/competitions/cifar-10/
# Out:
# cifar-10.zip  sampleSubmission.csv  train  trainLabels.csv

# %%
# import py7zr
# b = py7zr.SevenZipFile(r'./test.7z', 'r')
# a.extractall(path=r'./competitions/cifar-10/')
# b.close()

# %% [markdown]
# # 数据预处理

# %%
from pathlib import Path

DATA_DIR = Path("/content/competitions/cifar-10")

train_lables_file = DATA_DIR / "trainLabels.csv"
test_csv_file = DATA_DIR / "sampleSubmission.csv" #测试集模板csv文件
train_folder = DATA_DIR / "train"
test_folder = DATA_DIR / "test"


#所有的类别
class_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck',
]
# INSERT_YOUR_CODE
import pandas as pd

def load_image_paths_and_labels(labels_csv_path, images_folder):
    """
    读取labels_csv_path（trainLabels.csv），为每张图片拼接完整路径，并返回[(img_path, label), ...]的列表
    """
    df = pd.read_csv(labels_csv_path)
    items = []
    for idx, row in df.iterrows():
        img_name = row['id']  # 假设csv第一列是id（去掉.jpg后缀的文件名）
        label = row['label']
        img_path = images_folder / f"{img_name}.png"  # cifar10可能是png，也可能是jpg，请确保格式一致
        if not img_path.exists():
            img_path = images_folder / f"{img_name}.jpg"
        items.append( (str(img_path), label) )
    return items

# 示例调用方法
train_items = load_image_paths_and_labels(train_lables_file, train_folder)
test_items = load_image_paths_and_labels(test_csv_file, test_folder)

import pprint
pprint.pprint(train_items[:5])
# Out:
# [('/content/competitions/cifar-10/train/1.png', 'frog'),
#  ('/content/competitions/cifar-10/train/2.png', 'truck'),
#  ('/content/competitions/cifar-10/train/3.png', 'truck'),
#  ('/content/competitions/cifar-10/train/4.png', 'deer'),
#  ('/content/competitions/cifar-10/train/5.png', 'automobile')]

# %%
# INSERT_YOUR_CODE
import pandas as pd

# 将train_items分为45000条用于训练，5000条用于验证
train_items_ = train_items[:45000]
valid_items_ = train_items[45000:]

# 转为DataFrame
train_df = pd.DataFrame(train_items_, columns=["img_path", "label"])
valid_df = pd.DataFrame(valid_items_, columns=["img_path", "label"])
test_df = pd.DataFrame(test_items, columns=["img_path", "label"])

# %%
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

class Cifar10Dataset(Dataset):
    df_map = {
        "train": train_df,
        "eval": valid_df,
        "test": test_df
    }
    label_to_idx = {label: idx for idx, label in enumerate(class_names)} # 类别映射为idx
    idx_to_label = {idx: label for idx, label in enumerate(class_names)} # idx映射为类别,为了test使用
    def __init__(self, mode, transform=None):
        self.df = self.df_map.get(mode, None) # 获取对应模式的df，不同字符串对应不同模式
        if self.df is None:
            raise ValueError("mode should be one of train, val, test, but got {}".format(mode))
        # assert self.df, "df is None"
        self.transform = transform

    def __getitem__(self, index):
        img_path, label = self.df.iloc[index] # 获取图片路径和标签
        img = Image.open(img_path).convert('RGB')
        # # img 转换为 channel first
        # img = img.transpose((2, 0, 1))
        # transform
        img = self.transform(img) # 数据增强
        # label 转换为 idx
        label = self.label_to_idx[label]
        return img, label

    def __len__(self):
        return self.df.shape[0] # 返回df的行数,样本数

IMAGE_SIZE = 32
mean, std = [0.4914, 0.4822, 0.4465], [0.247, 0.243, 0.261]

transforms_train = transforms.Compose([
        # resize
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)), #缩放
        # random rotation 40
        transforms.RandomRotation(40), #随机旋转
        # horizaontal flip
        transforms.RandomHorizontalFlip(),  #随机水平翻转
        transforms.ToTensor(), #转换为tensor
        transforms.Normalize(mean, std) #标准化
    ]) #数据增强

transforms_eval = transforms.Compose([
        # resize
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
# ToTensor还将图像的维度从[height, width, channels]转换为[channels, height, width]。
train_ds = Cifar10Dataset("train", transforms_train)
eval_ds = Cifar10Dataset("eval", transforms_eval)

# %%
# 对train_ds计算均值和标准差
# from torch.utils.data import DataLoader
# import torch
#
# loader = DataLoader(train_ds, batch_size=64, shuffle=False, num_workers=2)
#
# mean = torch.zeros(3)
# std = torch.zeros(3)
# n_pixels = 0
#
# for images, _ in loader:  # images: [B, 3, H, W]
#     batch_pixels = images.shape[0] * images.shape[2] * images.shape[3]
#     mean += images.sum([0, 2, 3])
#     std += (images ** 2).sum([0, 2, 3])
#     n_pixels += batch_pixels
#
# mean /= n_pixels
# std = torch.sqrt(std / n_pixels - mean ** 2)
#
# print("train_ds按通道均值:", mean)
# print("train_ds按通道标准差:", std)

# %%
from torch.utils.data import DataLoader

# 创建训练集和验证集的DataLoader
batch_size = 32

train_loader = DataLoader(
    train_ds,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据
)

test_loader = DataLoader(
    eval_ds,
    batch_size=batch_size,
    shuffle=False,  # 测试时不需要打乱
)

print(f"训练集DataLoader批次数: {len(train_loader)}")
print(f"测试集DataLoader批次数: {len(test_loader)}")
print(f"每个批次大小: {batch_size}")

# 查看一个批次的数据
for batch_images, batch_labels in train_loader:
    print(f"批次图像张量形状: {batch_images.shape}")
    print(f"批次标签张量形状: {batch_labels.shape}")
    print(batch_labels)
    break
# Out:
# 训练集DataLoader批次数: 1407
# 测试集DataLoader批次数: 157
# 每个批次大小: 32
# 批次图像张量形状: torch.Size([32, 3, 32, 32])
# 批次标签张量形状: torch.Size([32])
# tensor([0, 3, 2, 9, 7, 5, 6, 6, 2, 4, 5, 1, 2, 8, 3, 6, 0, 9, 1, 3, 2, 7, 5, 7,
#         4, 5, 5, 8, 3, 3, 8, 9])

# %% [markdown]
# # 搭建模型

# %%
import torch.nn as nn
import torch

class VGG11(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.features = nn.Sequential(
            # 1
            nn.Conv2d(3, 64, kernel_size=3, padding=1),  # (64, 32, 32)
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),       # (64, 16, 16)

            # 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1), # (128, 16,16)
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),        # (128, 8,8)

            # 3
            nn.Conv2d(128, 256, kernel_size=3, padding=1), # (256,8,8)
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1), # (256,8,8)
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),        # (256,4,4)

            # 4
            nn.Conv2d(256, 512, kernel_size=3, padding=1), # (512,4,4)
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1), # (512,4,4)
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),        # (512,2,2)

            # 5
            nn.Conv2d(512, 512, kernel_size=3, padding=1), # (512,2,2)
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1), # (512,2,2)
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),        # (512,1,1)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),  # (batch, 512*1*1)
            nn.Linear(512, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, num_classes),
        )

        self._initialize_weights()

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

# 初始化模型
model = VGG11(num_classes=len(class_names))

# %%
128*16*16*256
# Out:
# 8388608

# %%
# 使用随机输入对模型进行一次前向计算以验证模型结构是否正确
import torch

dummy_input = torch.randn(32, 3, 32, 32)
output = model(dummy_input) #前向传播/前向计算/正向传播
print(f"Output shape: {output.shape}")
# Out:
# Output shape: torch.Size([32, 10])

# %%
# 输出model每一层的参数量
total_params = 0  # 初始化总参数量为0
print("各层参数量统计：")  # 打印参数统计表头
for name, param in model.named_parameters():  # 遍历模型中所有需要优化的参数
    if param.requires_grad:  # 只有需要梯度更新的参数才统计
        num_params = param.numel()  # 计算当前参数的元素总数
        total_params += num_params  # 更新总参数量
        print(f"{name}: {num_params}")  # 输出当前层的参数量
print(f"模型总参数量: {total_params}")  # 输出模型总参数量
# Out:
# 各层参数量统计：
# features.0.weight: 1728
# features.0.bias: 64
# features.3.weight: 73728
# features.3.bias: 128
# features.6.weight: 294912
# features.6.bias: 256
# features.8.weight: 589824
# features.8.bias: 256
# features.11.weight: 1179648
# features.11.bias: 512
# features.13.weight: 2359296
# features.13.bias: 512
# features.16.weight: 2359296
# features.16.bias: 512
# features.18.weight: 2359296
# features.18.bias: 512
# classifier.1.weight: 262144
# classifier.1.bias: 512
# classifier.3.weight: 5120
# classifier.3.bias: 10
# 模型总参数量: 9488266

# %%
32*3*3*64
# Out:
# 18432

# %% [markdown]
# # 训练

# %%
import torch.nn as nn
import torch.optim as optim

# 初始化交叉熵损失函数，内部会做softmax
criterion = nn.CrossEntropyLoss()

# 初始化优化器（这里选用Adam，也可以使用SGD等）
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import wangdao_train
# ========================== 早停机制配置 ==========================

# 初始化EarlyStopping，对验证集性能长期不提升时提前终止训练
early_stopping = wangdao_train.EarlyStopping(
    patience=10,      # 当超过10个评估周期(val_loss)无提升则早停
    min_delta=0.001,  # 只有当val_loss较历史最优减少超过0.001才认为有提升
    mode='min'        # 'min'表示以val_loss越小越好为目标监控
)

# ========================== 模型检查点配置 ==========================

# 初始化模型检查点对象，每次val_loss取得历史新低时保存一次模型参数
model_checkpoint = wangdao_train.ModelCheckpoint(
    filepath='./checkpoints/cifar10_model_epoch_{epoch}.ckpt',  # 保存路径，{epoch}会被当前轮数替换
    monitor='val_acc',         # 监控指标为验证集损失
    save_best_only=True,        # 只保存val_loss最优时的模型
    mode='max',                 # val_loss越小越好
    min_delta=0.001             # 只有val_loss较上次最好记录下降超过0.001时才保存
)

# 假设train_loader和val_loader已定义，device已经设为"cuda"或"cpu"
trainer = wangdao_train.Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    eval_step=100,
    model_checkpoint=model_checkpoint,

)

# 设定训练轮数
num_epochs = 20

# 开始训练
trainer.train(num_epochs)
# Out:
# [Step 100] Val Loss: 1.6875 Val Acc: 0.3448
# [Step 200] Val Loss: 1.7418 Val Acc: 0.3246
# [Step 300] Val Loss: 1.7115 Val Acc: 0.3554
# [Step 400] Val Loss: 1.6165 Val Acc: 0.3802
# [Step 500] Val Loss: 1.6185 Val Acc: 0.3816
# [Step 600] Val Loss: 1.5530 Val Acc: 0.4054
# [Step 700] Val Loss: 1.5345 Val Acc: 0.4222
# [Step 800] Val Loss: 1.6307 Val Acc: 0.3772
# [Step 900] Val Loss: 1.5878 Val Acc: 0.4058
# [Step 1000] Val Loss: 1.5551 Val Acc: 0.3914
# [Step 1100] Val Loss: 1.4608 Val Acc: 0.4590
# [Step 1200] Val Loss: 1.5144 Val Acc: 0.4366
# [Step 1300] Val Loss: 1.4348 Val Acc: 0.4658
# [Step 1400] Val Loss: 1.4527 Val Acc: 0.4672
# Epoch [1/20]  Train Loss: 1.6335  Train Acc: 0.3875
# [Step 1500] Val Loss: 1.4262 Val Acc: 0.4704
# [Step 1600] Val Loss: 1.4112 Val Acc: 0.4832
# [Step 1700] Val Loss: 1.3795 Val Acc: 0.4810
# [Step 1800] Val Loss: 1.3928 Val Acc: 0.4846
# [Step 1900] Val Loss: 1.3819 Val Acc: 0.4926
# [Step 2000] Val Loss: 1.3945 Val Acc: 0.4784
# [Step 2100] Val Loss: 1.3921 Val Acc: 0.4890
# [Step 2200] Val Loss: 1.3430 Val Acc: 0.4960
# [Step 2300] Val Loss: 1.3616 Val Acc: 0.4946
# [Step 2400] Val Loss: 1.3313 Val Acc: 0.5132
# [Step 2500] Val Loss: 1.2920 Val Acc: 0.5300
# [Step 2600] Val Loss: 1.3049 Val Acc: 0.5224
# [Step 2700] Val Loss: 1.2802 Val Acc: 0.5294
# [Step 2800] Val Loss: 1.2892 Val Acc: 0.5364
# Epoch [2/20]  Train Loss: 1.4286  Train Acc: 0.4778
# [Step 2900] Val Loss: 1.3258 Val Acc: 0.5004
# [Step 3000] Val Loss: 1.3174 Val Acc: 0.5246
# [Step 3100] Val Loss: 1.3068 Val Acc: 0.5284
# [Step 3200] Val Loss: 1.2588 Val Acc: 0.5506
# [Step 3300] Val Loss: 1.2394 Val Acc: 0.5552
# [Step 3400] Val Loss: 1.2570 Val Acc: 0.5396
# [Step 3500] Val Loss: 1.2848 Val Acc: 0.5372
# [Step 3600] Val Loss: 1.3020 Val Acc: 0.5486
# [Step 3700] Val Loss: 1.2729 Val Acc: 0.5336
# [Step 3800] Val Loss: 1.2093 Val Acc: 0.5660
# [Step 3900] Val Loss: 1.1982 Val Acc: 0.5660
# [Step 4000] Val Loss: 1.2505 Val Acc: 0.5496
# [Step 4100] Val Loss: 1.2218 Val Acc: 0.5578
# [Step 4200] Val Loss: 1.2181 Val Acc: 0.5684
# Epoch [3/20]  Train Loss: 1.3291  Train Acc: 0.5196
# [Step 4300] Val Loss: 1.1958 Val Acc: 0.5708
# [Step 4400] Val Loss: 1.1823 Val Acc: 0.5872
# [Step 4500] Val Loss: 1.2313 Val Acc: 0.5534
# [Step 4600] Val Loss: 1.2053 Val Acc: 0.5766
# [Step 4700] Val Loss: 1.1693 Val Acc: 0.5816
# [Step 4800] Val Loss: 1.1781 Val Acc: 0.5762
# [Step 4900] Val Loss: 1.1640 Val Acc: 0.5824
# [Step 5000] Val Loss: 1.1733 Val Acc: 0.5714
# [Step 5100] Val Loss: 1.1996 Val Acc: 0.5708
# [Step 5200] Val Loss: 1.1866 Val Acc: 0.5654
# [Step 5300] Val Loss: 1.1628 Val Acc: 0.5694
# [Step 5400] Val Loss: 1.1160 Val Acc: 0.6128
# [Step 5500] Val Loss: 1.1545 Val Acc: 0.5934
# [Step 5600] Val Loss: 1.1045 Val Acc: 0.6072
# Epoch [4/20]  Train Loss: 1.2583  Train Acc: 0.5464
# [Step 5700] Val Loss: 1.1183 Val Acc: 0.6064
# [Step 5800] Val Loss: 1.1597 Val Acc: 0.5852
# [Step 5900] Val Loss: 1.1818 Val Acc: 0.5898
# [Step 6000] Val Loss: 1.1269 Val Acc: 0.5968
# [Step 6100] Val Loss: 1.1055 Val Acc: 0.6058
# [Step 6200] Val Loss: 1.0925 Val Acc: 0.6146
# [Step 6300] Val Loss: 1.1254 Val Acc: 0.5956
# [Step 6400] Val Loss: 1.0752 Val Acc: 0.6162
# [Step 6500] Val Loss: 1.0933 Val Acc: 0.6220
# [Step 6600] Val Loss: 1.0676 Val Acc: 0.6208
# [Step 6700] Val Loss: 1.1086 Val Acc: 0.6108
# [Step 6800] Val Loss: 1.0523 Val Acc: 0.6254
# [Step 6900] Val Loss: 1.1244 Val Acc: 0.6016
# [Step 7000] Val Loss: 1.0906 Val Acc: 0.6186
# Epoch [5/20]  Train Loss: 1.1885  Train Acc: 0.5772
# [Step 7100] Val Loss: 1.0568 Val Acc: 0.6344
# [Step 7200] Val Loss: 1.1024 Val Acc: 0.6120
# [Step 7300] Val Loss: 1.0679 Val Acc: 0.6210
# [Step 7400] Val Loss: 1.0609 Val Acc: 0.6212
# [Step 7500] Val Loss: 1.0716 Val Acc: 0.6228
# [Step 7600] Val Loss: 1.1007 Val Acc: 0.6102
# [Step 7700] Val Loss: 1.0772 Val Acc: 0.6232
# [Step 7800] Val Loss: 1.0800 Val Acc: 0.6168
# [Step 7900] Val Loss: 1.0420 Val Acc: 0.6302
# [Step 8000] Val Loss: 1.0476 Val Acc: 0.6370
# [Step 8100] Val Loss: 1.0270 Val Acc: 0.6420
# [Step 8200] Val Loss: 1.1177 Val Acc: 0.6022
# [Step 8300] Val Loss: 1.0373 Val Acc: 0.6346
# [Step 8400] Val Loss: 1.0329 Val Acc: 0.6406
# Epoch [6/20]  Train Loss: 1.1378  Train Acc: 0.5953
# [Step 8500] Val Loss: 1.0104 Val Acc: 0.6378
# [Step 8600] Val Loss: 1.0493 Val Acc: 0.6292
# [Step 8700] Val Loss: 1.0669 Val Acc: 0.6332
# [Step 8800] Val Loss: 1.0090 Val Acc: 0.6474
# [Step 8900] Val Loss: 1.0434 Val Acc: 0.6360
# [Step 9000] Val Loss: 1.0512 Val Acc: 0.6266
# [Step 9100] Val Loss: 1.0262 Val Acc: 0.6372
# [Step 9200] Val Loss: 1.0051 Val Acc: 0.6394
# [Step 9300] Val Loss: 1.0404 Val Acc: 0.6346
# [Step 9400] Val Loss: 1.0269 Val Acc: 0.6394
# [Step 9500] Val Loss: 0.9864 Val Acc: 0.6586
# [Step 9600] Val Loss: 1.0285 Val Acc: 0.6490
# [Step 9700] Val Loss: 0.9863 Val Acc: 0.6594
# [Step 9800] Val Loss: 0.9754 Val Acc: 0.6618
# Epoch [7/20]  Train Loss: 1.1009  Train Acc: 0.6128
# [Step 9900] Val Loss: 0.9813 Val Acc: 0.6448
# [Step 10000] Val Loss: 0.9637 Val Acc: 0.6594
# [Step 10100] Val Loss: 0.9982 Val Acc: 0.6534
# [Step 10200] Val Loss: 0.9733 Val Acc: 0.6538
# [Step 10300] Val Loss: 0.9639 Val Acc: 0.6600
# [Step 10400] Val Loss: 0.9904 Val Acc: 0.6476
# [Step 10500] Val Loss: 0.9953 Val Acc: 0.6516
# [Step 10600] Val Loss: 0.9439 Val Acc: 0.6638
# [Step 10700] Val Loss: 0.9796 Val Acc: 0.6592
# [Step 10800] Val Loss: 0.9768 Val Acc: 0.6598
# [Step 10900] Val Loss: 0.9914 Val Acc: 0.6670
# [Step 11000] Val Loss: 0.9561 Val Acc: 0.6704
# [Step 11100] Val Loss: 0.9718 Val Acc: 0.6598
# [Step 11200] Val Loss: 0.9602 Val Acc: 0.6646
# Epoch [8/20]  Train Loss: 1.0591  Train Acc: 0.6284
# [Step 11300] Val Loss: 0.9952 Val Acc: 0.6602
# [Step 11400] Val Loss: 0.9117 Val Acc: 0.6820
# [Step 11500] Val Loss: 0.9566 Val Acc: 0.6640
# [Step 11600] Val Loss: 0.9947 Val Acc: 0.6586
# [Step 11700] Val Loss: 0.9783 Val Acc: 0.6542
# [Step 11800] Val Loss: 0.9387 Val Acc: 0.6748
# [Step 11900] Val Loss: 0.9715 Val Acc: 0.6664
# [Step 12000] Val Loss: 0.9727 Val Acc: 0.6574
# [Step 12100] Val Loss: 0.9598 Val Acc: 0.6654
# [Step 12200] Val Loss: 0.9351 Val Acc: 0.6746
# [Step 12300] Val Loss: 0.9449 Val Acc: 0.6678
# [Step 12400] Val Loss: 0.9785 Val Acc: 0.6626
# [Step 12500] Val Loss: 0.9442 Val Acc: 0.6694
# [Step 12600] Val Loss: 0.9471 Val Acc: 0.6694
# Epoch [9/20]  Train Loss: 1.0265  Train Acc: 0.6403
# [Step 12700] Val Loss: 0.9903 Val Acc: 0.6582
# [Step 12800] Val Loss: 0.9615 Val Acc: 0.6628
# [Step 12900] Val Loss: 0.9394 Val Acc: 0.6812
# [Step 13000] Val Loss: 0.9204 Val Acc: 0.6866
# [Step 13100] Val Loss: 0.9103 Val Acc: 0.6888
# [Step 13200] Val Loss: 0.9720 Val Acc: 0.6568
# [Step 13300] Val Loss: 0.9376 Val Acc: 0.6788
# [Step 13400] Val Loss: 0.9833 Val Acc: 0.6678
# [Step 13500] Val Loss: 0.9505 Val Acc: 0.6698
# [Step 13600] Val Loss: 0.9184 Val Acc: 0.6818
# [Step 13700] Val Loss: 0.9070 Val Acc: 0.6874
# [Step 13800] Val Loss: 0.9624 Val Acc: 0.6692
# [Step 13900] Val Loss: 0.9126 Val Acc: 0.6860
# [Step 14000] Val Loss: 0.9103 Val Acc: 0.6862
# Epoch [10/20]  Train Loss: 0.9998  Train Acc: 0.6510
# [Step 14100] Val Loss: 0.9196 Val Acc: 0.6838
# [Step 14200] Val Loss: 0.9397 Val Acc: 0.6726
# [Step 14300] Val Loss: 0.8947 Val Acc: 0.6894
# [Step 14400] Val Loss: 0.8912 Val Acc: 0.6934
# [Step 14500] Val Loss: 0.9255 Val Acc: 0.6850
# [Step 14600] Val Loss: 0.8981 Val Acc: 0.6898
# [Step 14700] Val Loss: 0.9806 Val Acc: 0.6556
# [Step 14800] Val Loss: 0.9101 Val Acc: 0.6772
# [Step 14900] Val Loss: 0.9120 Val Acc: 0.6868
# [Step 15000] Val Loss: 0.8944 Val Acc: 0.6910
# [Step 15100] Val Loss: 0.9168 Val Acc: 0.6820
# [Step 15200] Val Loss: 0.9279 Val Acc: 0.6782
# [Step 15300] Val Loss: 0.8985 Val Acc: 0.6864
# [Step 15400] Val Loss: 0.9062 Val Acc: 0.6922
# Epoch [11/20]  Train Loss: 0.9759  Train Acc: 0.6598
# [Step 15500] Val Loss: 0.8719 Val Acc: 0.6922
# [Step 15600] Val Loss: 0.9459 Val Acc: 0.6794
# [Step 15700] Val Loss: 0.9492 Val Acc: 0.6736
# [Step 15800] Val Loss: 0.8926 Val Acc: 0.6958
# [Step 15900] Val Loss: 0.8942 Val Acc: 0.6938
# [Step 16000] Val Loss: 0.8705 Val Acc: 0.7034
# [Step 16100] Val Loss: 0.8831 Val Acc: 0.6904
# [Step 16200] Val Loss: 0.8757 Val Acc: 0.6954
# [Step 16300] Val Loss: 0.8778 Val Acc: 0.7018
# [Step 16400] Val Loss: 0.8600 Val Acc: 0.7120
# [Step 16500] Val Loss: 0.9160 Val Acc: 0.6914
# [Step 16600] Val Loss: 0.8679 Val Acc: 0.7036
# [Step 16700] Val Loss: 0.9040 Val Acc: 0.6924
# [Step 16800] Val Loss: 0.8947 Val Acc: 0.6922
# Epoch [12/20]  Train Loss: 0.9455  Train Acc: 0.6694
# [Step 16900] Val Loss: 0.9082 Val Acc: 0.6992
# [Step 17000] Val Loss: 0.8806 Val Acc: 0.6894
# [Step 17100] Val Loss: 0.9012 Val Acc: 0.6948
# [Step 17200] Val Loss: 0.9017 Val Acc: 0.6910
# [Step 17300] Val Loss: 0.8675 Val Acc: 0.7090
# [Step 17400] Val Loss: 0.8807 Val Acc: 0.6902
# [Step 17500] Val Loss: 0.8558 Val Acc: 0.7094
# [Step 17600] Val Loss: 0.8443 Val Acc: 0.7116
# [Step 17700] Val Loss: 0.8732 Val Acc: 0.7018
# [Step 17800] Val Loss: 0.8441 Val Acc: 0.7096
# [Step 17900] Val Loss: 0.9138 Val Acc: 0.6966
# [Step 18000] Val Loss: 0.8365 Val Acc: 0.7170
# [Step 18100] Val Loss: 0.8661 Val Acc: 0.7016
# [Step 18200] Val Loss: 0.8439 Val Acc: 0.7118
# Epoch [13/20]  Train Loss: 0.9281  Train Acc: 0.6780
# [Step 18300] Val Loss: 0.8371 Val Acc: 0.7118
# [Step 18400] Val Loss: 0.8654 Val Acc: 0.7112
# [Step 18500] Val Loss: 0.8573 Val Acc: 0.7158
# [Step 18600] Val Loss: 0.8244 Val Acc: 0.7156
# [Step 18700] Val Loss: 0.9143 Val Acc: 0.6912
# [Step 18800] Val Loss: 0.8606 Val Acc: 0.7074
# [Step 18900] Val Loss: 0.8923 Val Acc: 0.6934
# [Step 19000] Val Loss: 0.8486 Val Acc: 0.7060
# [Step 19100] Val Loss: 0.8450 Val Acc: 0.7110
# [Step 19200] Val Loss: 0.8714 Val Acc: 0.7034
# [Step 19300] Val Loss: 0.8286 Val Acc: 0.7186
# [Step 19400] Val Loss: 0.8271 Val Acc: 0.7220
# [Step 19500] Val Loss: 0.8119 Val Acc: 0.7162
# [Step 19600] Val Loss: 0.8614 Val Acc: 0.7094
# Epoch [14/20]  Train Loss: 0.9085  Train Acc: 0.6851
# [Step 19700] Val Loss: 0.8353 Val Acc: 0.7192
# [Step 19800] Val Loss: 0.8589 Val Acc: 0.7108
# [Step 19900] Val Loss: 0.8367 Val Acc: 0.7164
# [Step 20000] Val Loss: 0.8733 Val Acc: 0.7110
# [Step 20100] Val Loss: 0.8307 Val Acc: 0.7200
# [Step 20200] Val Loss: 0.8373 Val Acc: 0.7168
# [Step 20300] Val Loss: 0.8234 Val Acc: 0.7188
# [Step 20400] Val Loss: 0.8416 Val Acc: 0.7076
# [Step 20500] Val Loss: 0.8587 Val Acc: 0.7074
# [Step 20600] Val Loss: 0.8337 Val Acc: 0.7186
# [Step 20700] Val Loss: 0.8402 Val Acc: 0.7156
# [Step 20800] Val Loss: 0.8441 Val Acc: 0.7160
# [Step 20900] Val Loss: 0.8726 Val Acc: 0.7032
# [Step 21000] Val Loss: 0.8369 Val Acc: 0.7134
# [Step 21100] Val Loss: 0.8300 Val Acc: 0.7142
# Epoch [15/20]  Train Loss: 0.8964  Train Acc: 0.6906
# [Step 21200] Val Loss: 0.8316 Val Acc: 0.7106
# [Step 21300] Val Loss: 0.8719 Val Acc: 0.7054
# [Step 21400] Val Loss: 0.8746 Val Acc: 0.7082
# [Step 21500] Val Loss: 0.8584 Val Acc: 0.7088
# [Step 21600] Val Loss: 0.8430 Val Acc: 0.7124
# [Step 21700] Val Loss: 0.8501 Val Acc: 0.7120
# [Step 21800] Val Loss: 0.8370 Val Acc: 0.7182
# [Step 21900] Val Loss: 0.8379 Val Acc: 0.7182
# [Step 22000] Val Loss: 0.8434 Val Acc: 0.7170
# [Step 22100] Val Loss: 0.8202 Val Acc: 0.7214
# [Step 22200] Val Loss: 0.8342 Val Acc: 0.7180
# [Step 22300] Val Loss: 0.8700 Val Acc: 0.7118
# [Step 22400] Val Loss: 0.8443 Val Acc: 0.7152
# [Step 22500] Val Loss: 0.8159 Val Acc: 0.7256
# Epoch [16/20]  Train Loss: 0.8760  Train Acc: 0.6984
# [Step 22600] Val Loss: 0.8195 Val Acc: 0.7174
# [Step 22700] Val Loss: 0.8864 Val Acc: 0.7060
# [Step 22800] Val Loss: 0.8263 Val Acc: 0.7240
# [Step 22900] Val Loss: 0.8409 Val Acc: 0.7174
# [Step 23000] Val Loss: 0.8145 Val Acc: 0.7312
# [Step 23100] Val Loss: 0.8338 Val Acc: 0.7252
# [Step 23200] Val Loss: 0.8325 Val Acc: 0.7174
# [Step 23300] Val Loss: 0.8195 Val Acc: 0.7190
# [Step 23400] Val Loss: 0.8534 Val Acc: 0.7172
# [Step 23500] Val Loss: 0.8332 Val Acc: 0.7250
# [Step 23600] Val Loss: 0.8329 Val Acc: 0.7156
# [Step 23700] Val Loss: 0.8121 Val Acc: 0.7232
# [Step 23800] Val Loss: 0.8365 Val Acc: 0.7174
# [Step 23900] Val Loss: 0.8059 Val Acc: 0.7278
# Epoch [17/20]  Train Loss: 0.8580  Train Acc: 0.7022
# [Step 24000] Val Loss: 0.8402 Val Acc: 0.7150
# [Step 24100] Val Loss: 0.7934 Val Acc: 0.7296
# [Step 24200] Val Loss: 0.8277 Val Acc: 0.7222
# [Step 24300] Val Loss: 0.8250 Val Acc: 0.7156
# [Step 24400] Val Loss: 0.8186 Val Acc: 0.7230
# [Step 24500] Val Loss: 0.8239 Val Acc: 0.7240
# [Step 24600] Val Loss: 0.8029 Val Acc: 0.7302
# [Step 24700] Val Loss: 0.8238 Val Acc: 0.7268
# [Step 24800] Val Loss: 0.8079 Val Acc: 0.7208
# [Step 24900] Val Loss: 0.8022 Val Acc: 0.7294
# [Step 25000] Val Loss: 0.8136 Val Acc: 0.7296
# [Step 25100] Val Loss: 0.8044 Val Acc: 0.7260
# [Step 25200] Val Loss: 0.7981 Val Acc: 0.7256
# [Step 25300] Val Loss: 0.8306 Val Acc: 0.7220
# Epoch [18/20]  Train Loss: 0.8526  Train Acc: 0.7083
# [Step 25400] Val Loss: 0.8423 Val Acc: 0.7206
# [Step 25500] Val Loss: 0.8315 Val Acc: 0.7158
# [Step 25600] Val Loss: 0.7974 Val Acc: 0.7276
# [Step 25700] Val Loss: 0.8078 Val Acc: 0.7270
# [Step 25800] Val Loss: 0.7916 Val Acc: 0.7336
# [Step 25900] Val Loss: 0.7918 Val Acc: 0.7250
# [Step 26000] Val Loss: 0.8805 Val Acc: 0.7114
# [Step 26100] Val Loss: 0.8157 Val Acc: 0.7198
# [Step 26200] Val Loss: 0.7984 Val Acc: 0.7350
# [Step 26300] Val Loss: 0.7831 Val Acc: 0.7316
# [Step 26400] Val Loss: 0.7986 Val Acc: 0.7344
# [Step 26500] Val Loss: 0.8460 Val Acc: 0.7216
# [Step 26600] Val Loss: 0.7852 Val Acc: 0.7350
# [Step 26700] Val Loss: 0.8133 Val Acc: 0.7282
# Epoch [19/20]  Train Loss: 0.8372  Train Acc: 0.7126
# [Step 26800] Val Loss: 0.8079 Val Acc: 0.7304
# [Step 26900] Val Loss: 0.7844 Val Acc: 0.7292
# [Step 27000] Val Loss: 0.7995 Val Acc: 0.7374
# [Step 27100] Val Loss: 0.7872 Val Acc: 0.7422
# [Step 27200] Val Loss: 0.8249 Val Acc: 0.7300
# [Step 27300] Val Loss: 0.8122 Val Acc: 0.7308
# [Step 27400] Val Loss: 0.8068 Val Acc: 0.7302
# [Step 27500] Val Loss: 0.7840 Val Acc: 0.7392
# [Step 27600] Val Loss: 0.7829 Val Acc: 0.7310
# [Step 27700] Val Loss: 0.7801 Val Acc: 0.7426
# [Step 27800] Val Loss: 0.7822 Val Acc: 0.7326
# [Step 27900] Val Loss: 0.7636 Val Acc: 0.7398
# [Step 28000] Val Loss: 0.8324 Val Acc: 0.7218
# [Step 28100] Val Loss: 0.7999 Val Acc: 0.7352
# Epoch [20/20]  Train Loss: 0.8215  Train Acc: 0.7204

# %%
trainer.plot_curves()

# %%
# !ls

# %%
# !ls /content/competitions/cifar-10/test/1.png

# %%
test_items = load_image_paths_and_labels(test_csv_file, test_folder)

# %%
test_df = pd.DataFrame(test_items, columns=["img_path", "label"])
test_df.head()

# %%
# 构建test_ds并推理，预测结果写入csv

# 假设Cifar10Dataset类、transforms_eval和idx_to_label已定义
test_ds = Cifar10Dataset("test", transforms_eval)
test_loader_final = torch.utils.data.DataLoader(test_ds, batch_size=128, shuffle=False)

all_preds = []
model.eval()
with torch.no_grad():
    for data in test_loader_final:
        images = data[0]
        images = images.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)
        all_preds.extend(predicted.cpu().numpy().tolist())

# 利用idx_to_label将id转换为类别名
all_labels = [Cifar10Dataset.idx_to_label[idx] for idx in all_preds]

import pandas as pd
# 生成带id的DataFrame
df = pd.DataFrame({
    "id": list(range(len(all_labels))),
    "label": all_labels
})
df.to_csv("cifar10_test_pred.csv", index=False)
