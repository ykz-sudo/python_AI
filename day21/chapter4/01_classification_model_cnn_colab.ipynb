# %%
# 导入必要的库
import matplotlib as mpl
import matplotlib.pyplot as plt
# 在Jupyter notebook中内联显示图表
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
from tqdm.auto import tqdm  # 进度条库
import torch
import torch.nn as nn
import torch.nn.functional as F

# 打印Python版本信息
print(sys.version_info)

# 打印各个库的版本信息
for module in mpl, np, pd, sklearn, torch:
    print(module.__name__, module.__version__)

# 设置设备：如果有GPU则使用GPU，否则使用CPU
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)
# Out:
# sys.version_info(major=3, minor=12, micro=3, releaselevel='final', serial=0)
# matplotlib 3.10.8
# numpy 2.4.0
# pandas 2.3.3
# sklearn 1.8.0
# torch 2.9.1+cpu
# cpu

# %% [markdown]
# # 数据预处理

# %%
# 加载FashionMNIST数据集
from torchvision import datasets, transforms

# 定义数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 将PIL图像或numpy数组转换为tensor,ToTensor会自动将图像转换为tensor，并归一化到[0,1]范围
    # transforms.Normalize((0.5,), (0.5,))  # 标准化到[-1, 1]范围
])

# 下载并加载训练集
train_dataset = datasets.FashionMNIST(
    root='./data',  # 数据存储路径
    train=True,     # 加载训练集
    download=True,  # 如果数据不存在则下载
    transform=transform
)

# 下载并加载测试集
test_dataset = datasets.FashionMNIST(
    root='./data',
    train=False,    # 加载测试集
    download=True,
    transform=transform
)

# 打印数据集信息
print(f"训练集大小: {len(train_dataset)}")
print(f"测试集大小: {len(test_dataset)}")
print(f"训练集数据类型: {type(train_dataset)}")
print(f"单个dataset元素类型: {type(train_dataset[0])}")
print(f"单个dataset元素是什么: {train_dataset[0]}")
print(f"图像尺寸: {train_dataset[0][0].shape}")
# lables在这个路径https://github.com/zalandoresearch/fashion-mnist
# FashionMNIST类别标签
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
print(f"类别数量: {len(class_names)}")
print(f"类别标签: {class_names}")
# Out:
# 训练集大小: 60000
# 测试集大小: 10000
# 训练集数据类型: <class 'torchvision.datasets.mnist.FashionMNIST'>
# 单个dataset元素类型: <class 'tuple'>
# 单个dataset元素是什么: (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#           0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0039, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#           0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#           0.0157, 0.0000, 0.0000, 0.0118],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#           0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0471, 0.0392, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#           0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#           0.3020, 0.5098, 0.2824, 0.0588],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#           0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#           0.5529, 0.3451, 0.6745, 0.2588],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#           0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#           0.4824, 0.7686, 0.8980, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#           0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#           0.8745, 0.9608, 0.6784, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#           0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#           0.8627, 0.9529, 0.7922, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#           0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#           0.8863, 0.7725, 0.8196, 0.2039],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#           0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#           0.9608, 0.4667, 0.6549, 0.2196],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#           0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#           0.8510, 0.8196, 0.3608, 0.0000],
#          [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#           0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#           0.8549, 1.0000, 0.3020, 0.0000],
#          [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#           0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#           0.8784, 0.9569, 0.6235, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#           0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#           0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#           0.9137, 0.9333, 0.8431, 0.0000],
#          [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#           0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#           0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#           0.8627, 0.9098, 0.9647, 0.0000],
#          [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#           0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#           0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#           0.8706, 0.8941, 0.8824, 0.0000],
#          [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#           0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#           0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#           0.8745, 0.8784, 0.8980, 0.1137],
#          [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#           0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#           0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#           0.8627, 0.8667, 0.9020, 0.2627],
#          [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#           0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#           0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#           0.7098, 0.8039, 0.8078, 0.4510],
#          [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#           0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#           0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#           0.6549, 0.6941, 0.8235, 0.3608],
#          [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#           0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#           0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#           0.7529, 0.8471, 0.6667, 0.0000],
#          [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#           0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#           0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#           0.3882, 0.2275, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#           0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]]), 9)
# 图像尺寸: torch.Size([1, 28, 28])
# 类别数量: 10
# 类别标签: ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print(train_dataset.classes)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
import matplotlib.pyplot as plt

# 显示前15张图片，每行5张，共3行
fig, axes = plt.subplots(3, 5, figsize=(12, 8))
fig.suptitle('FashionMNIST Dataset - First 15 Images', fontsize=16)

for i in range(15):
    row = i // 5
    col = i % 5

    # 获取图像和标签
    image, label = train_dataset[i]

    # 将tensor转换为numpy数组并去掉通道维度
    image_np = image.squeeze().numpy()

    # 显示图像
    axes[row, col].imshow(image_np, cmap='gray')
    axes[row, col].set_title(f'{class_names[label]}')
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
from torch.utils.data import DataLoader

# 创建训练集和验证集的DataLoader
batch_size = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据
    num_workers=2  # 使用多进程加载数据
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,  # 测试时不需要打乱
    num_workers=2
)

print(f"训练集DataLoader批次数: {len(train_loader)}")
print(f"测试集DataLoader批次数: {len(test_loader)}")
print(f"每个批次大小: {batch_size}")

# 查看一个批次的数据
train_iter = iter(train_loader)
batch_images, batch_labels = next(train_iter)
print(f"批次图像张量形状: {batch_images.shape}")
print(f"批次标签张量形状: {batch_labels.shape}")
print(batch_labels)
# Out:
# 训练集DataLoader批次数: 1875
# 测试集DataLoader批次数: 313
# 每个批次大小: 32
# 批次图像张量形状: torch.Size([32, 1, 28, 28])
# 批次标签张量形状: torch.Size([32])
# tensor([2, 2, 8, 4, 5, 7, 2, 1, 5, 7, 7, 9, 3, 2, 2, 8, 4, 3, 2, 9, 2, 7, 2, 6,
#         8, 3, 1, 7, 4, 8, 8, 2])

# %%
28*28
# Out:
# 784

# %% [markdown]
# 在PyTorch中，`DataLoader`是一个迭代器，它封装了数据的加载和预处理过程，使得在训练机器学习模型时可以方便地批量加载数据。`DataLoader`主要负责以下几个方面：
#
# 1. **批量加载数据**：`DataLoader`可以将数据集（Dataset）切分为更小的批次（batch），每次迭代提供一小批量数据，而不是单个数据点。这有助于模型学习数据中的统计依赖性，并且可以更高效地利用GPU等硬件的并行计算能力。
#
# 2. **数据打乱**：默认情况下，`DataLoader`会在每个epoch（训练周期）开始时打乱数据的顺序。这有助于模型训练时避免陷入局部最优解，并且可以提高模型的泛化能力。
#
# 3. **多线程数据加载**：`DataLoader`支持多线程（通过参数`num_workers`）来并行地加载数据，这可以显著减少训练过程中的等待时间，尤其是在处理大规模数据集时。
#
# 4. **数据预处理**：`DataLoader`可以与`transforms`结合使用，对加载的数据进行预处理，如归一化、标准化、数据增强等操作。
#
# 5. **内存管理**：`DataLoader`负责管理数据的内存使用，确保在训练过程中不会耗尽内存资源。
#
# 6. **易用性**：`DataLoader`提供了一个简单的接口，可以很容易地集成到训练循环中。

# %% [markdown]
# # 搭建模型

# %%
import torch.nn as nn

class FashionCNN(nn.Module):
    def __init__(self):
        super(FashionCNN, self).__init__()
        # 输入张量的形状为 (batch_size, 1, 28, 28)
        
        # 第1个卷积层：输入通道为1，输出通道为32，卷积核为3x3，padding=1保持输出尺寸不变 -> (batch, 32, 28, 28)
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        # 第2个卷积层：输入32通道，输出32通道（同上），不改变空间尺寸 -> (batch, 32, 28, 28)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        # 最大池化层：2x2窗口，步长为2，将空间尺寸减半 -> (batch, 32, 14, 14)
        self.pool = nn.MaxPool2d(2, 2)

        # 第3个卷积层：输入32通道，输出64通道，3x3卷积，padding=1 -> (batch, 64, 14, 14)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        # 第4个卷积层：输入64通道，输出64通道，3x3卷积，padding=1 -> (batch, 64, 14, 14)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        # 再次池化，减半 -> (batch, 64, 7, 7)

        # 第5个卷积层：输入64通道，输出128通道，3x3卷积，padding=1 -> (batch, 128, 7, 7)
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        # 第6个卷积层：输入128通道，输出128通道，3x3卷积，padding=1 -> (batch, 128, 7, 7)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        # 池化后 -> (batch, 128, 3, 3)

        # ReLU激活函数，高效地引入非线性，参数inplace=True节省内存
        self.relu = nn.ReLU(inplace=True)
        # 张量展平成一维，准备进入全连接层
        self.flatten = nn.Flatten()
        # 第1个全连接层：输入128*3*3（前一层展平后的长度），输出128个特征
        self.fc1 = nn.Linear(128 * 3 * 3, 128)
        # 第2个全连接层：输出类别数为10，对应FashionMNIST的10个类别
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        # 前向传播定义
        # 第一组卷积 + ReLU
        x = self.relu(self.conv1(x))  # 形状: (batch, 32, 28, 28)
        x = self.relu(self.conv2(x))  # 形状: (batch, 32, 28, 28)
        x = self.pool(x)              # 形状: (batch, 32, 14, 14)

        # 第二组卷积 + ReLU
        x = self.relu(self.conv3(x))  # 形状: (batch, 64, 14, 14)
        x = self.relu(self.conv4(x))  # 形状: (batch, 64, 14, 14)
        x = self.pool(x)              # 形状: (batch, 64, 7, 7)

        # 第三组卷积 + ReLU
        x = self.relu(self.conv5(x))  # 形状: (batch, 128, 7, 7)
        x = self.relu(self.conv6(x))  # 形状: (batch, 128, 7, 7)
        x = self.pool(x)              # 形状: (batch, 128, 3, 3)

        # 展平成一维
        x = self.flatten(x)           # 形状: (batch, 128*3*3)
        # 全连接层 + ReLU
        x = self.relu(self.fc1(x))    # 形状: (batch, 128)
        # 最终分类层
        x = self.fc2(x)               # 形状: (batch, 10)
        return x

# 实例化模型
model = FashionCNN()

# %%
# 使用随机输入对模型进行一次前向计算以验证模型结构是否正确
import torch

dummy_input = torch.randn(32, 1, 28, 28)  # batch_size=1, channels=1, height=28, width=28
output = model(dummy_input) #前向传播/前向计算/正向传播
print(f"Output shape: {output.shape}")
# Out:
# Output shape: torch.Size([32, 10])

# %%
# 输出model每一层的参数量
total_params = 0  # 初始化总参数量为0
print("各层参数量统计：")  # 打印参数统计表头
print(model.named_parameters())

for name, param in model.named_parameters():  # 遍历模型中所有需要优化的参数
    if param.requires_grad:  # 只有需要梯度更新的参数才统计
        # .numel() 是 PyTorch 张量（Tensor）的方法，用于返回张量中元素的总数。
        # 例如：一个形状为(2,3)的张量，numel()返回6，常用来统计模型参数总数。
        num_params = param.numel()  # 计算当前参数的元素总数
        total_params += num_params  # 更新总参数量
        print(f"{name}: {num_params}")  # 输出当前层的参数量
print(f"模型总参数量: {total_params}")  # 输出模型总参数量
# Out:
# 各层参数量统计：
# <generator object Module.named_parameters at 0x0000020DCF6A1940>
# conv1.weight: 288
# conv1.bias: 32
# conv2.weight: 9216
# conv2.bias: 32
# conv3.weight: 18432
# conv3.bias: 64
# conv4.weight: 36864
# conv4.bias: 64
# conv5.weight: 73728
# conv5.bias: 128
# conv6.weight: 147456
# conv6.bias: 128
# fc1.weight: 147456
# fc1.bias: 128
# fc2.weight: 1280
# fc2.bias: 10
# 模型总参数量: 435306

# %%
32*3*3*64
# Out:
# 18432

# %% [markdown]
# # 训练

# %%
import torch.nn as nn
import torch.optim as optim

# 初始化交叉熵损失函数，内部会做softmax
criterion = nn.CrossEntropyLoss()

# 初始化优化器（这里选用Adam，也可以使用SGD等）
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import wangdao_train
# 假设train_loader和val_loader已定义，device已经设为"cuda"或"cpu"
trainer = wangdao_train.Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    eval_step=500
)

# 设定训练轮数
num_epochs = 20

# 开始训练
trainer.train(num_epochs)
# Out:
# [Step 500] Val Loss: 0.5322 Val Acc: 0.8076
# [Step 1000] Val Loss: 0.4199 Val Acc: 0.8400
# [Step 1500] Val Loss: 0.3790 Val Acc: 0.8588
# Epoch [1/20]  Train Loss: 0.4875  Train Acc: 0.8186
# [Step 2000] Val Loss: 0.3915 Val Acc: 0.8604
# [Step 2500] Val Loss: 0.3317 Val Acc: 0.8741
# [Step 3000] Val Loss: 0.3038 Val Acc: 0.8899
# [Step 3500] Val Loss: 0.2926 Val Acc: 0.8926
# Epoch [2/20]  Train Loss: 0.2970  Train Acc: 0.8884
# [Step 4000] Val Loss: 0.3174 Val Acc: 0.8825
# [Step 4500] Val Loss: 0.2807 Val Acc: 0.8974
# [Step 5000] Val Loss: 0.2852 Val Acc: 0.8961
# [Step 5500] Val Loss: 0.2815 Val Acc: 0.8983
# Epoch [3/20]  Train Loss: 0.2473  Train Acc: 0.9073
# [Step 6000] Val Loss: 0.2666 Val Acc: 0.9039
# [Step 6500] Val Loss: 0.2577 Val Acc: 0.9035
# [Step 7000] Val Loss: 0.2559 Val Acc: 0.9066
# [Step 7500] Val Loss: 0.2565 Val Acc: 0.9080
# Epoch [4/20]  Train Loss: 0.2122  Train Acc: 0.9208
# [Step 8000] Val Loss: 0.2493 Val Acc: 0.9110
# [Step 8500] Val Loss: 0.2368 Val Acc: 0.9110
# [Step 9000] Val Loss: 0.2479 Val Acc: 0.9122
# Epoch [5/20]  Train Loss: 0.1885  Train Acc: 0.9299
# [Step 9500] Val Loss: 0.2415 Val Acc: 0.9176
# [Step 10000] Val Loss: 0.2262 Val Acc: 0.9220
# [Step 10500] Val Loss: 0.2463 Val Acc: 0.9185
# [Step 11000] Val Loss: 0.2370 Val Acc: 0.9139
# Epoch [6/20]  Train Loss: 0.1667  Train Acc: 0.9378
# [Step 11500] Val Loss: 0.2420 Val Acc: 0.9193
# [Step 12000] Val Loss: 0.2490 Val Acc: 0.9142
# [Step 12500] Val Loss: 0.2427 Val Acc: 0.9153
# [Step 13000] Val Loss: 0.2318 Val Acc: 0.9187
# Epoch [7/20]  Train Loss: 0.1491  Train Acc: 0.9441
# [Step 13500] Val Loss: 0.2567 Val Acc: 0.9185
# [Step 14000] Val Loss: 0.2449 Val Acc: 0.9198
# [Step 14500] Val Loss: 0.2575 Val Acc: 0.9195
# [Step 15000] Val Loss: 0.2358 Val Acc: 0.9213
# Epoch [8/20]  Train Loss: 0.1331  Train Acc: 0.9495
# [Step 15500] Val Loss: 0.2726 Val Acc: 0.9172
# [Step 16000] Val Loss: 0.2636 Val Acc: 0.9227
# [Step 16500] Val Loss: 0.2522 Val Acc: 0.9149
# Epoch [9/20]  Train Loss: 0.1191  Train Acc: 0.9553
# [Step 17000] Val Loss: 0.2576 Val Acc: 0.9215
# [Step 17500] Val Loss: 0.2869 Val Acc: 0.9153
# [Step 18000] Val Loss: 0.3234 Val Acc: 0.9060
# [Step 18500] Val Loss: 0.2584 Val Acc: 0.9179
# Epoch [10/20]  Train Loss: 0.1061  Train Acc: 0.9597
# [Step 19000] Val Loss: 0.2958 Val Acc: 0.9220
# [Step 19500] Val Loss: 0.2896 Val Acc: 0.9202
# [Step 20000] Val Loss: 0.2785 Val Acc: 0.9177
# [Step 20500] Val Loss: 0.2942 Val Acc: 0.9179
# Epoch [11/20]  Train Loss: 0.0973  Train Acc: 0.9637
# [Step 21000] Val Loss: 0.3101 Val Acc: 0.9195
# [Step 21500] Val Loss: 0.2813 Val Acc: 0.9191
# [Step 22000] Val Loss: 0.2794 Val Acc: 0.9193
# [Step 22500] Val Loss: 0.3324 Val Acc: 0.9124
# Epoch [12/20]  Train Loss: 0.0890  Train Acc: 0.9662
# [Step 23000] Val Loss: 0.3408 Val Acc: 0.9172
# [Step 23500] Val Loss: 0.3291 Val Acc: 0.9085
# [Step 24000] Val Loss: 0.3399 Val Acc: 0.9139
# Epoch [13/20]  Train Loss: 0.0816  Train Acc: 0.9687
# [Step 24500] Val Loss: 0.3473 Val Acc: 0.9183
# [Step 25000] Val Loss: 0.3207 Val Acc: 0.9141
# [Step 25500] Val Loss: 0.3275 Val Acc: 0.9157
# [Step 26000] Val Loss: 0.3522 Val Acc: 0.9078
# Epoch [14/20]  Train Loss: 0.0758  Train Acc: 0.9719
# [Step 26500] Val Loss: 0.3745 Val Acc: 0.9160
# [Step 27000] Val Loss: 0.4027 Val Acc: 0.9140
# [Step 27500] Val Loss: 0.4194 Val Acc: 0.9095
# [Step 28000] Val Loss: 0.3793 Val Acc: 0.9167
# Epoch [15/20]  Train Loss: 0.0710  Train Acc: 0.9739
# [Step 28500] Val Loss: 0.4109 Val Acc: 0.9144
# [Step 29000] Val Loss: 0.3809 Val Acc: 0.9193
# [Step 29500] Val Loss: 0.3460 Val Acc: 0.9147
# [Step 30000] Val Loss: 0.3721 Val Acc: 0.9185
# Epoch [16/20]  Train Loss: 0.0678  Train Acc: 0.9749
# [Step 30500] Val Loss: 0.4008 Val Acc: 0.9203
# [Step 31000] Val Loss: 0.4529 Val Acc: 0.9110
# [Step 31500] Val Loss: 0.3463 Val Acc: 0.9174
# Epoch [17/20]  Train Loss: 0.0659  Train Acc: 0.9748
# [Step 32000] Val Loss: 0.3768 Val Acc: 0.9196
# [Step 32500] Val Loss: 0.3703 Val Acc: 0.9176
# [Step 33000] Val Loss: 0.3761 Val Acc: 0.9150
# [Step 33500] Val Loss: 0.3997 Val Acc: 0.9166
# Epoch [18/20]  Train Loss: 0.0634  Train Acc: 0.9774
# [Step 34000] Val Loss: 0.4266 Val Acc: 0.9191
# [Step 34500] Val Loss: 0.4219 Val Acc: 0.9187
# [Step 35000] Val Loss: 0.4346 Val Acc: 0.9135
# [Step 35500] Val Loss: 0.4225 Val Acc: 0.9104
# Epoch [19/20]  Train Loss: 0.0591  Train Acc: 0.9789
# [Step 36000] Val Loss: 0.3864 Val Acc: 0.9155
# [Step 36500] Val Loss: 0.3773 Val Acc: 0.9202
# [Step 37000] Val Loss: 0.3889 Val Acc: 0.9165
# [Step 37500] Val Loss: 0.3867 Val Acc: 0.9183
# Epoch [20/20]  Train Loss: 0.0618  Train Acc: 0.9779

# %%
trainer.plot_curves()

# %% [markdown]
# # 标准化后重新初始化一个模型对象，训练对象

# %%
# 加载FashionMNIST数据集
from torchvision import datasets, transforms

# 定义数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 将PIL图像或numpy数组转换为tensor,ToTensor会自动将图像转换为tensor，并归一化到[0,1]范围
    # transforms.Normalize((0.2860,), (0.3205,))  # 标准化到[-1, 1]范围
])

# 下载并加载训练集
train_dataset = datasets.FashionMNIST(
    root='./data',  # 数据存储路径
    train=True,     # 加载训练集
    download=True,  # 如果数据不存在则下载
    transform=transform
)

# 下载并加载测试集
test_dataset = datasets.FashionMNIST(
    root='./data',
    train=False,    # 加载测试集
    download=True,
    transform=transform
)

# 打印数据集信息
print(f"训练集大小: {len(train_dataset)}")
print(f"测试集大小: {len(test_dataset)}")

# lables在这个路径https://github.com/zalandoresearch/fashion-mnist
# FashionMNIST类别标签
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
print(f"类别数量: {len(class_names)}")
print(f"类别标签: {class_names}")
# Out:
# 训练集大小: 60000
# 测试集大小: 10000
# 类别数量: 10
# 类别标签: ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
import torch  # 导入PyTorch库

# 计算整个训练集的均值和标准差
loader = torch.utils.data.DataLoader(train_dataset, batch_size=5000, shuffle=False, num_workers=0)  # 构建数据加载器，一次加载5000张图片
n_samples = 0  # 初始化样本数量
mean = 0.0     # 初始化均值
std = 0.0      # 初始化标准差

for images, _ in loader:  # 遍历数据加载器，每个batch返回(images, labels)
    # images: [batch_size, 1, 28, 28]
    batch_samples = images.size(0)  # 当前batch的图片张数
    images = images.view(batch_samples, -1)  # 展平图片为二维，方便计算，[batch_size, 784]
    mean += images.mean(1).sum()    # 计算每张图片的均值后求和，累加到总均值
    std += images.std(1).sum()      # 计算每张图片的标准差后求和，累加到总标准差
    n_samples += batch_samples      # 累加样本数量

mean /= n_samples  # 求所有图片均值的均值
std /= n_samples   # 求所有图片标准差的均值

print(f"训练集均值: {mean.item():.4f}")      # 打印训练集的均值
print(f"训练集标准差: {std.item():.4f}")     # 打印训练集的标准差
# Out:
# 训练集均值: 0.2860
# 训练集标准差: 0.3205

# %%
mean = 0.
std = 0.
n_pixels = 0

for images, _ in loader:
    # images: [B, 1, 28, 28]
    batch_pixels = images.numel()  # B * 1 * 28 * 28
    mean += images.sum()
    std  += (images ** 2).sum()
    n_pixels += batch_pixels

mean /= n_pixels
std = torch.sqrt(std / n_pixels - mean ** 2)

print(mean.item(), std.item())
# Out:
# 0.28604063391685486 0.3530242443084717

# %%
from torch.utils.data import DataLoader

# 创建训练集和验证集的DataLoader
batch_size = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据
    num_workers=2  # 使用多进程加载数据
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,  # 测试时不需要打乱
    num_workers=2
)

# %%
import torch.nn as nn

class TwoLayerNN(nn.Module):
    def __init__(self):
        super(TwoLayerNN, self).__init__()
        self.flatten = nn.Flatten() # 展平操作，将28*28的图像展平为784维的向量
        self.fc1 = nn.Linear(28*28, 300) # 全连接层，将784维的向量映射为300维的向量
        self.relu1 = nn.ReLU() # 激活函数，ReLU函数
        self.fc2 = nn.Linear(300, 100) # 全连接层，将300维的向量映射为100维的向量
        self.relu2 = nn.ReLU() # 激活函数，ReLU函数
        self.fc3 = nn.Linear(100, 10) # 全连接层，将100维的向量映射为10维的向量

    def forward(self, x):
        x = self.flatten(x)

        x = self.fc1(x)

        x = self.relu1(x)

        x = self.fc2(x)

        x = self.relu2(x)

        x = self.fc3(x)

        return x

model_normalize = TwoLayerNN()
print(model_normalize)
# Out:
# TwoLayerNN(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=784, out_features=300, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=300, out_features=100, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
model_normalize.state_dict()
# Out:
# OrderedDict([('fc1.weight',
#               tensor([[ 0.0165,  0.0095,  0.0112,  ...,  0.0269, -0.0171,  0.0354],
#                       [ 0.0336,  0.0312,  0.0004,  ..., -0.0079,  0.0107,  0.0296],
#                       [ 0.0139, -0.0181, -0.0033,  ...,  0.0220, -0.0154, -0.0232],
#                       ...,
#                       [-0.0313,  0.0084, -0.0083,  ...,  0.0119,  0.0148, -0.0353],
#                       [-0.0138, -0.0242,  0.0090,  ..., -0.0275,  0.0167, -0.0291],
#                       [ 0.0261,  0.0142, -0.0340,  ..., -0.0179, -0.0243, -0.0262]])),
#              ('fc1.bias',
#               tensor([-1.9733e-02,  1.6514e-02, -1.1910e-03,  1.0991e-02, -2.1651e-02,
#                       -2.4981e-02,  1.4105e-02, -3.9016e-03, -1.1525e-02, -2.9280e-03,
#                       -2.1551e-02,  1.3722e-02, -2.8950e-02,  6.5651e-03,  1.1076e-02,
#                        5.0341e-03,  2.5169e-02,  1.5508e-02,  3.2460e-02, -1.8127e-03,
#                        3.3932e-02,  1.2078e-02,  5.7024e-03, -1.6225e-02, -2.6763e-02,
#                        1.6004e-02, -3.5333e-02,  3.4221e-02,  3.1251e-02,  5.8436e-03,
#                        1.4683e-02, -3.0667e-03, -4.0906e-03,  4.9116e-03, -3.1865e-02,
#                        1.8420e-02, -1.8746e-02, -1.4880e-02, -3.3672e-05, -9.7739e-04,
#                       -2.5562e-02,  2.8783e-02, -1.2294e-02,  1.1834e-02,  2.3089e-02,
#                       -5.0430e-03, -3.0807e-03, -1.4336e-02, -5.1686e-03, -1.3987e-02,
#                        2.5437e-04,  3.3885e-02, -2.3963e-02, -2.5266e-02, -1.3717e-02,
#                       -1.7790e-02,  2.8930e-02, -8.9297e-03, -9.1626e-03, -2.1842e-02,
#                        2.7357e-02, -3.2902e-02,  3.1524e-02,  2.3245e-02, -3.0790e-04,
#                       -3.4862e-02,  3.1536e-02, -3.2979e-02,  3.4002e-02, -1.0599e-02,
#                        2.5538e-02, -1.8488e-03,  2.9145e-03, -2.5121e-02,  1.1252e-02,
#                        2.1402e-02,  1.2288e-02, -9.7453e-03,  2.3797e-02, -2.1551e-02,
#                        7.6977e-04,  2.9742e-02, -1.8363e-02,  3.1125e-02,  1.3524e-02,
#                        3.3261e-02,  2.3205e-02,  1.2148e-02,  1.7040e-02,  3.0488e-02,
#                        1.9022e-02, -2.7251e-02, -3.4132e-02,  4.8490e-03,  3.2916e-02,
#                       -2.6314e-02, -1.3041e-02,  1.4734e-02, -2.8640e-02,  2.2776e-02,
#                        1.1848e-02,  2.1260e-02, -2.6069e-02, -1.7437e-02, -3.0651e-03,
#                       -3.1391e-02,  1.9806e-02,  2.5128e-02, -1.5703e-02,  2.4332e-02,
#                       -1.7068e-02, -2.5094e-02, -1.3394e-02, -1.8473e-02,  2.3210e-02,
#                       -1.8958e-02,  1.1330e-02,  2.4499e-02, -9.8168e-03, -1.9137e-02,
#                        5.2638e-04,  3.4235e-02, -6.1391e-03,  2.4257e-02, -2.7216e-02,
#                        2.1896e-02, -1.1535e-02,  1.5346e-02, -9.0634e-03,  2.9117e-02,
#                       -3.0537e-02, -3.4596e-02,  3.5689e-02,  2.6488e-02,  2.6168e-02,
#                        3.3234e-02, -1.3186e-02, -2.4795e-02, -2.6622e-02, -3.2424e-03,
#                        1.1367e-02, -9.2688e-03, -6.5071e-04, -3.2165e-02, -1.1450e-02,
#                        1.5837e-03,  1.5007e-03, -3.2572e-03, -3.1667e-02, -1.4011e-02,
#                       -5.5622e-03,  7.5107e-03, -3.0521e-02,  3.0438e-02,  3.1911e-02,
#                       -1.3447e-02,  2.0445e-02, -1.2958e-02,  1.1524e-02, -1.2056e-02,
#                       -6.0214e-03, -1.3995e-02,  3.3423e-02,  2.8778e-02, -2.0868e-02,
#                        3.2314e-02, -1.9841e-02, -2.4513e-02, -3.3489e-02,  2.5036e-02,
#                       -2.7850e-02, -3.1420e-02,  1.6764e-03,  8.0020e-03,  3.8880e-03,
#                       -1.9076e-02, -2.3016e-03,  1.8478e-02,  2.2483e-02, -2.0267e-02,
#                       -3.2513e-02,  1.4554e-02, -7.8769e-03,  2.7226e-02, -9.5244e-03,
#                       -2.8823e-03,  3.0812e-02, -3.5141e-02,  2.1101e-03,  4.9483e-03,
#                        2.1756e-02,  1.1787e-02, -3.1520e-02, -2.9859e-02,  1.2065e-03,
#                       -2.9656e-02,  2.8371e-02, -2.8380e-02,  1.7901e-02, -9.7933e-03,
#                       -3.3787e-02,  1.3834e-02, -3.3420e-02, -1.0212e-02,  2.2368e-02,
#                       -1.8762e-02,  2.2322e-02,  1.3457e-03,  7.3106e-03, -6.5023e-03,
#                       -3.9281e-03, -1.6837e-02,  1.2732e-02, -1.1018e-02,  3.4493e-02,
#                       -2.3322e-02, -3.0236e-02,  7.5550e-03,  3.5234e-02,  3.5788e-03,
#                        3.0174e-02, -2.6173e-02, -2.0428e-02, -1.6408e-02, -3.0708e-02,
#                       -9.8867e-03, -2.8844e-02,  2.1687e-02, -3.1060e-02, -2.7342e-02,
#                       -1.2615e-02,  4.9036e-03,  2.8166e-02, -2.9016e-02, -2.0283e-02,
#                       -9.2998e-03,  2.0809e-02, -2.2259e-02,  3.2261e-02, -1.3334e-02,
#                        2.1738e-02,  3.1230e-02, -2.2508e-02, -2.6224e-02, -1.4630e-02,
#                       -3.1969e-02,  3.4884e-02,  2.7705e-02,  2.4328e-02, -3.3086e-02,
#                       -6.5317e-03, -1.2852e-02,  8.9665e-03, -2.7010e-02,  1.3904e-02,
#                       -2.3183e-02,  1.6556e-02,  3.4509e-02,  2.4820e-02,  3.5351e-03,
#                        2.7584e-02, -3.3519e-02,  2.2510e-03, -8.6733e-03,  2.0840e-02,
#                       -3.3477e-02, -2.1999e-02,  7.2058e-03, -3.1286e-02, -3.3871e-02,
#                        1.7766e-03, -1.2131e-02,  8.0275e-03,  6.7222e-03,  4.6270e-03,
#                       -7.0274e-03, -9.8758e-03, -6.9846e-03, -3.1422e-02, -2.7055e-02,
#                        2.3451e-02, -2.9299e-02, -1.3090e-02,  3.2330e-02, -1.1305e-02,
#                        1.6691e-02,  2.1748e-02,  1.6623e-02, -1.1412e-02,  3.3969e-02,
#                       -1.7510e-02,  5.5492e-03, -1.4427e-02, -2.2790e-02,  1.9169e-02,
#                       -1.7026e-02,  2.8106e-02,  2.1564e-02, -1.0253e-02, -2.6073e-02])),
#              ('fc2.weight',
#               tensor([[ 0.0168, -0.0265, -0.0398,  ..., -0.0201,  0.0514, -0.0232],
#                       [ 0.0247,  0.0039,  0.0389,  ..., -0.0163,  0.0259, -0.0324],
#                       [-0.0051, -0.0038, -0.0172,  ..., -0.0123,  0.0349, -0.0055],
#                       ...,
#                       [ 0.0165,  0.0186, -0.0372,  ...,  0.0122,  0.0415, -0.0139],
#                       [ 0.0190, -0.0096, -0.0354,  ..., -0.0276, -0.0054, -0.0570],
#                       [-0.0425,  0.0225,  0.0288,  ...,  0.0349,  0.0136, -0.0384]])),
#              ('fc2.bias',
#               tensor([-4.5484e-02, -5.5190e-02, -2.2060e-02,  2.7843e-02, -1.0733e-02,
#                       -4.2478e-02,  4.5533e-02,  1.0410e-02,  4.0871e-02,  5.0449e-02,
#                        4.5280e-02, -5.4125e-02, -5.3766e-02, -2.1473e-02,  2.6640e-02,
#                       -5.0789e-02,  1.5170e-02,  3.7834e-02,  5.6438e-03, -2.9675e-02,
#                       -3.2827e-02,  1.1581e-02,  1.6297e-02, -1.3013e-02, -9.1783e-03,
#                       -4.6023e-02,  5.2734e-02, -1.8277e-04,  4.4968e-02, -5.2105e-03,
#                       -2.6306e-02, -7.0904e-03,  1.5742e-02, -5.1950e-02, -3.0036e-02,
#                       -2.2812e-02, -3.1331e-02, -4.4640e-02, -5.2127e-02,  3.0612e-02,
#                        3.0813e-02,  2.1893e-02, -1.6965e-02, -2.7980e-02, -2.9629e-02,
#                       -6.5418e-03,  4.8169e-02,  3.7011e-03,  5.1350e-02,  5.8041e-05,
#                        5.6562e-02,  4.6900e-02, -2.2896e-02, -1.8902e-02, -3.0875e-02,
#                       -2.3730e-02,  2.0977e-03,  4.6665e-03,  3.5291e-02,  1.0956e-02,
#                       -5.0361e-02,  2.1019e-02,  4.0332e-02, -4.9639e-02, -1.6468e-02,
#                        1.1601e-02,  4.2267e-02, -1.4937e-02,  5.7280e-03, -2.1228e-03,
#                       -4.7429e-02, -2.3217e-02, -4.8860e-02,  2.9908e-02,  3.3137e-02,
#                        5.4631e-02,  2.6467e-02,  5.2701e-02,  1.3425e-02,  1.9975e-02,
#                       -1.8630e-03,  4.5773e-02, -1.0487e-02,  3.6872e-02, -5.0549e-02,
#                        1.5111e-02,  1.8946e-02,  4.9586e-02, -5.4362e-03, -3.3542e-02,
#                       -2.9472e-02,  3.8011e-02, -1.8584e-02, -3.1893e-02,  2.4437e-02,
#                        3.6216e-02,  5.2345e-03,  5.5011e-03, -4.7479e-02, -4.1392e-02])),
#              ('fc3.weight',
#               tensor([[-0.0924, -0.0449, -0.0499,  0.0542, -0.0607,  0.0930, -0.0098, -0.0408,
#                        -0.0887, -0.0361,  0.0080, -0.0136, -0.0055,  0.0629, -0.0042, -0.0853,
#                         0.0329,  0.0547, -0.0792, -0.0590, -0.0523, -0.0515, -0.0936, -0.0879,
#                         0.0537,  0.0027, -0.0035,  0.0844,  0.0950, -0.0361, -0.0894,  0.0276,
#                         0.0541, -0.0831,  0.0654,  0.0249, -0.0724,  0.0768,  0.0583,  0.0557,
#                         0.0425, -0.0871, -0.0334,  0.0562, -0.0242,  0.0640, -0.0391,  0.0155,
#                         0.0473,  0.0835,  0.0148, -0.0238, -0.0378, -0.0200, -0.0734,  0.0536,
#                        -0.0804, -0.0940, -0.0487,  0.0820, -0.0687,  0.0606,  0.0450, -0.0851,
#                         0.0205,  0.0458,  0.0701,  0.0829, -0.0586,  0.0952, -0.0587,  0.0073,
#                        -0.0071,  0.0162, -0.0042, -0.0688, -0.0781, -0.0156, -0.0288,  0.0147,
#                         0.0785,  0.0933,  0.0924, -0.0305,  0.0633,  0.0704, -0.0536, -0.0554,
#                        -0.0613, -0.0851, -0.0890,  0.0302,  0.0937,  0.0091, -0.0987, -0.0711,
#                         0.0448, -0.0363, -0.0201,  0.0805],
#                       [ 0.0902,  0.0268, -0.0430,  0.0103,  0.0518,  0.0816, -0.0051,  0.0945,
#                        -0.0417,  0.0460,  0.0136,  0.0679, -0.0171,  0.0393, -0.0563, -0.0284,
#                         0.0466, -0.0412,  0.0742,  0.0043, -0.0451,  0.0214, -0.0232,  0.0161,
#                         0.0121, -0.0335, -0.0450,  0.0095,  0.0530,  0.0114, -0.0293,  0.0147,
#                         0.0479, -0.0710, -0.0085, -0.0232, -0.0503,  0.0157, -0.0654, -0.0120,
#                         0.0188, -0.0317,  0.0015, -0.0367, -0.0102, -0.0103, -0.0278,  0.0749,
#                        -0.0549, -0.0034,  0.0504,  0.0842,  0.0672,  0.0590, -0.0246,  0.0860,
#                         0.0056,  0.0676,  0.0861, -0.0816,  0.0273,  0.0595,  0.0720, -0.0895,
#                         0.0044, -0.0440, -0.0709,  0.0864,  0.0616, -0.0306, -0.0169,  0.0175,
#                         0.0543, -0.0333, -0.0193,  0.0176,  0.0840,  0.0074,  0.0773,  0.0112,
#                        -0.0084, -0.0455,  0.0625,  0.0021,  0.0064,  0.0681,  0.0555, -0.0867,
#                        -0.0263,  0.0459, -0.0963,  0.0849, -0.0893, -0.0817, -0.0440,  0.0832,
#                        -0.0389,  0.0575,  0.0996,  0.0788],
#                       [-0.0175, -0.0425, -0.0751,  0.0614,  0.0683,  0.0988,  0.0302, -0.0427,
#                        -0.0340,  0.0834,  0.0853,  0.0570,  0.0395, -0.0472, -0.0110, -0.0159,
#                         0.0346,  0.0787,  0.0036,  0.0712,  0.0766,  0.0126,  0.0745,  0.0554,
#                        -0.0225, -0.0381, -0.0724,  0.0327, -0.0680, -0.0051,  0.0067, -0.0724,
#                        -0.0365,  0.0113,  0.0108, -0.0191,  0.0579, -0.0179,  0.0437,  0.0119,
#                         0.0794,  0.0512, -0.0033, -0.0667,  0.0410,  0.0613,  0.0528,  0.0881,
#                        -0.0285, -0.0929, -0.0737,  0.0392,  0.0639, -0.0290, -0.0437, -0.0464,
#                         0.0542, -0.0442,  0.0062,  0.0849,  0.0678,  0.0776,  0.0413, -0.0962,
#                         0.0446,  0.0239, -0.0385, -0.0173,  0.0016, -0.0090,  0.0827,  0.0292,
#                         0.0755,  0.0002, -0.0943,  0.0025,  0.0230, -0.0149, -0.0084,  0.0966,
#                         0.0931,  0.0943, -0.0496,  0.0165,  0.0137,  0.0519, -0.0588,  0.0109,
#                         0.0321, -0.0092,  0.0938, -0.0561, -0.0321,  0.0246, -0.0667, -0.0118,
#                        -0.0793, -0.0174, -0.0534,  0.0318],
#                       [-0.0763, -0.0562, -0.0809,  0.0721, -0.0192, -0.0640, -0.0702,  0.0993,
#                         0.0420,  0.0130,  0.0302, -0.0071,  0.0543,  0.0931, -0.0947,  0.0815,
#                        -0.0035, -0.0702,  0.0430,  0.0701,  0.0589,  0.0426, -0.0612,  0.0371,
#                         0.0806, -0.0135, -0.0160,  0.0754,  0.0529,  0.0792, -0.0428, -0.0121,
#                         0.0676, -0.0579,  0.0917,  0.0470,  0.0167, -0.0132,  0.0789, -0.0284,
#                        -0.0818, -0.0992, -0.0597, -0.0641, -0.0198,  0.0259,  0.0054,  0.0310,
#                        -0.0546, -0.0539, -0.0711,  0.0637,  0.0971,  0.0658, -0.0936, -0.0585,
#                         0.0315,  0.0800,  0.0085,  0.0579, -0.0418, -0.0003,  0.0767, -0.0910,
#                         0.0059,  0.0612, -0.0966, -0.0421,  0.0735,  0.0592, -0.0130,  0.0256,
#                        -0.0321,  0.0440,  0.0697,  0.0641,  0.0831, -0.0196,  0.0884,  0.0294,
#                         0.0532,  0.0460, -0.0706,  0.0877,  0.0387,  0.0336,  0.0213, -0.0283,
#                         0.0035, -0.0654,  0.0993,  0.0197, -0.0339,  0.0868,  0.0535,  0.0085,
#                         0.0271,  0.0550,  0.0086, -0.0032],
#                       [ 0.0746,  0.0292, -0.0742, -0.0146, -0.0456, -0.0459, -0.0576, -0.0931,
#                        -0.0857,  0.0593, -0.0449, -0.0691,  0.0992,  0.0566,  0.0901, -0.0579,
#                        -0.0996,  0.0846, -0.0329,  0.0378,  0.0991, -0.0798, -0.0944,  0.0176,
#                        -0.0019,  0.0704,  0.0687, -0.0632, -0.0543,  0.0897,  0.0792, -0.0777,
#                        -0.0878, -0.0921, -0.0295,  0.0026,  0.0253, -0.0916, -0.0735, -0.0336,
#                        -0.0308,  0.0796,  0.0412,  0.0423, -0.0005,  0.0438,  0.0611,  0.0250,
#                        -0.0995,  0.0249, -0.0103, -0.0112, -0.0420, -0.0224,  0.0514, -0.0242,
#                         0.0975,  0.0026, -0.0196, -0.0533, -0.0826,  0.0205,  0.0372,  0.0101,
#                        -0.0922,  0.0762, -0.0897,  0.0310, -0.0921,  0.0395,  0.0036, -0.0110,
#                         0.0916,  0.0754,  0.0781,  0.0743,  0.0761,  0.0319,  0.0971, -0.0768,
#                         0.0087, -0.0493,  0.0083,  0.0993,  0.0596, -0.0738,  0.0646, -0.0125,
#                        -0.1000, -0.0135, -0.0029, -0.0744, -0.0949,  0.0923, -0.0965, -0.0281,
#                        -0.0965, -0.0511,  0.0180,  0.0860],
#                       [ 0.0555,  0.0380,  0.0868,  0.0177,  0.0906,  0.0965,  0.0756, -0.0708,
#                         0.0479, -0.0905, -0.0130,  0.0034, -0.0926,  0.0810,  0.0314,  0.0150,
#                         0.0295, -0.0445,  0.0739,  0.0068,  0.0885, -0.0782,  0.0345, -0.0241,
#                        -0.0313, -0.0406, -0.0548,  0.0770, -0.0690,  0.0568,  0.0799,  0.0824,
#                         0.0502,  0.0949,  0.0312,  0.0048,  0.0701,  0.0450,  0.0031, -0.0891,
#                         0.0306, -0.0401, -0.0089, -0.0829,  0.0573, -0.0610, -0.0450, -0.0648,
#                         0.0850,  0.0750,  0.0539,  0.0814, -0.0156,  0.0970, -0.0887, -0.0940,
#                         0.0604,  0.0824, -0.0433, -0.0707,  0.0630,  0.0496, -0.0264,  0.0987,
#                        -0.0305, -0.0649, -0.0385,  0.0080, -0.0241, -0.0417,  0.0656,  0.0211,
#                        -0.0069,  0.0896,  0.0807,  0.0209,  0.0251, -0.0652, -0.0129,  0.0673,
#                        -0.0326, -0.0038,  0.0009,  0.0089,  0.0634, -0.0116, -0.0914,  0.0656,
#                        -0.0979, -0.0198,  0.0477,  0.0436, -0.0164, -0.0551,  0.0196,  0.0646,
#                         0.0074,  0.0864,  0.0085, -0.0447],
#                       [-0.0141,  0.0901, -0.0504, -0.0746, -0.0779,  0.0170, -0.0090,  0.0227,
#                         0.0407, -0.0777, -0.0558,  0.0124, -0.0638, -0.0045, -0.0418,  0.0329,
#                        -0.0725,  0.0373, -0.0392,  0.0941, -0.0007, -0.0028,  0.0594, -0.0940,
#                        -0.0120, -0.0596,  0.0589,  0.0696,  0.0103, -0.0401,  0.0227,  0.0787,
#                         0.0076, -0.0831,  0.0925,  0.0550,  0.0348,  0.0775,  0.0051, -0.0741,
#                        -0.0576, -0.0908,  0.0398, -0.0166,  0.0462, -0.0076,  0.0181, -0.0998,
#                         0.0432, -0.0914,  0.0578, -0.0313,  0.0952,  0.0074,  0.0661, -0.0052,
#                         0.0504, -0.0073, -0.0143, -0.0034,  0.0790,  0.0795,  0.0873,  0.0526,
#                         0.0713, -0.0225,  0.0033, -0.0995, -0.0797,  0.0097, -0.0008, -0.0613,
#                        -0.0829,  0.0064,  0.0840,  0.0243, -0.0201,  0.0572,  0.0855,  0.0701,
#                         0.0939,  0.0363, -0.0313,  0.0370, -0.0947,  0.0420, -0.0296, -0.0218,
#                        -0.0760, -0.0006,  0.0517,  0.0663,  0.0744,  0.0884, -0.0850,  0.0718,
#                        -0.0930,  0.0999, -0.0527,  0.0734],
#                       [ 0.0699,  0.0847, -0.0475, -0.0247, -0.0907,  0.0061, -0.0295, -0.0291,
#                        -0.0265,  0.0145, -0.0967, -0.0905,  0.0563, -0.0267,  0.0839, -0.0614,
#                         0.0999,  0.0063,  0.0130,  0.0634, -0.0182,  0.0853, -0.0702,  0.0006,
#                        -0.0804, -0.0374,  0.0581,  0.0315,  0.0324,  0.0382, -0.0789, -0.0620,
#                        -0.0969, -0.0804, -0.0394,  0.0221, -0.0184, -0.0847, -0.0820, -0.0359,
#                        -0.0220,  0.0157, -0.0864, -0.0479, -0.0981,  0.0283, -0.0049,  0.0196,
#                         0.0481, -0.0911,  0.0438, -0.0477, -0.0731, -0.0128, -0.0682,  0.0811,
#                         0.0593,  0.0539,  0.0785,  0.0361, -0.0996, -0.0623,  0.0359, -0.0089,
#                         0.0754,  0.0424, -0.0913,  0.0783, -0.0434, -0.0816, -0.0977,  0.0883,
#                         0.0787, -0.0568, -0.0045,  0.0886, -0.0565, -0.0729,  0.0134, -0.0569,
#                        -0.0354, -0.0693,  0.0057,  0.0632, -0.0787,  0.0973,  0.0146,  0.0932,
#                        -0.0829, -0.0715, -0.0661,  0.0055,  0.0276, -0.0475, -0.0822,  0.0788,
#                        -0.0829,  0.0922,  0.0222,  0.0885],
#                       [ 0.0458, -0.0195, -0.0643,  0.0701, -0.0109,  0.0477,  0.0854,  0.0512,
#                         0.0297,  0.0089, -0.0408, -0.0177,  0.0179, -0.0225,  0.0009, -0.0025,
#                         0.0691, -0.0646,  0.0531, -0.0530, -0.0048,  0.0584,  0.0461,  0.0416,
#                        -0.0517,  0.0870, -0.0875, -0.0139,  0.0116,  0.0885, -0.0264, -0.0473,
#                         0.0225,  0.0836, -0.0231, -0.0230, -0.0721,  0.0956,  0.0018,  0.0930,
#                        -0.0044, -0.0042,  0.0915,  0.0545,  0.0975, -0.0926,  0.0890, -0.0812,
#                        -0.0120,  0.0941, -0.0615, -0.0378, -0.0092,  0.0807,  0.0541, -0.0274,
#                         0.0901, -0.0720, -0.0891, -0.0008,  0.0276, -0.0776,  0.0417, -0.0766,
#                        -0.0036,  0.0111,  0.0749, -0.0699,  0.0544, -0.0792, -0.0541,  0.0587,
#                        -0.0783, -0.0720, -0.0003, -0.0131,  0.0407, -0.0685,  0.0998,  0.0781,
#                         0.0369, -0.0736,  0.0951, -0.0781,  0.0296, -0.0044, -0.0494, -0.0076,
#                        -0.0447,  0.0204,  0.0548,  0.0193, -0.0981, -0.0697, -0.0540,  0.0751,
#                        -0.0182,  0.0870,  0.0941,  0.0862],
#                       [-0.0538, -0.0321, -0.0095, -0.0836, -0.0471, -0.0836, -0.0410,  0.0589,
#                         0.0297,  0.0735, -0.0377,  0.0801,  0.0837, -0.0426, -0.0172,  0.0375,
#                        -0.0678,  0.0383,  0.0189, -0.0629,  0.0649, -0.0997, -0.0961,  0.0698,
#                         0.0976,  0.0788, -0.0415,  0.0601,  0.0987,  0.0154,  0.0061,  0.0561,
#                         0.0642,  0.0393, -0.0778,  0.0970, -0.0791, -0.0666,  0.0337,  0.0543,
#                         0.0559,  0.0914, -0.0668,  0.0389, -0.0086,  0.0380, -0.0002,  0.0762,
#                        -0.0511, -0.0498,  0.0368, -0.0823, -0.0298, -0.0840,  0.0789, -0.0553,
#                        -0.0611,  0.0428,  0.0706, -0.0624,  0.0056, -0.0284, -0.0456,  0.0187,
#                         0.0430,  0.0223, -0.0078, -0.0259,  0.0876, -0.0313,  0.0166, -0.0263,
#                         0.0279, -0.0725,  0.0542,  0.0964, -0.0982, -0.0823,  0.0915, -0.0833,
#                         0.0290,  0.0804, -0.0273, -0.0482,  0.0959, -0.0840,  0.0259,  0.0501,
#                         0.0453, -0.0912, -0.0737,  0.0382,  0.0069,  0.0771,  0.0003, -0.0144,
#                        -0.0785,  0.0064, -0.0423, -0.0386]])),
#              ('fc3.bias',
#               tensor([ 0.0206,  0.0966, -0.0516, -0.0168,  0.0624, -0.0209,  0.0801, -0.0422,
#                       -0.0284,  0.0692]))])

# %%
import torch.nn as nn
import torch.optim as optim

# 初始化交叉熵损失函数，内部会做softmax
criterion = nn.CrossEntropyLoss()

# 初始化优化器（这里选用Adam，也可以使用SGD等）
optimizer_normalize = optim.SGD(model_normalize.parameters(), lr=0.001)

# %%
import wangdao_train
# 假设train_loader和val_loader已定义，device已经设为"cuda"或"cpu"
trainer_normalize = wangdao_train.Trainer(
    model=model_normalize,
    train_loader=train_loader,
    val_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer_normalize,
    device=device
)

# 设定训练轮数
num_epochs = 20

# 开始训练
trainer_normalize.train(num_epochs)
# Out:
# [Step 100] Val Loss: 2.2908 Val Acc: 0.1041
# [Step 200] Val Loss: 2.2808 Val Acc: 0.1308
# [Step 300] Val Loss: 2.2710 Val Acc: 0.1905
# [Step 400] Val Loss: 2.2613 Val Acc: 0.2327
# [Step 500] Val Loss: 2.2516 Val Acc: 0.2723
# [Step 600] Val Loss: 2.2418 Val Acc: 0.3160
# [Step 700] Val Loss: 2.2313 Val Acc: 0.3319
# [Step 800] Val Loss: 2.2207 Val Acc: 0.3347
# [Step 900] Val Loss: 2.2093 Val Acc: 0.3704
# [Step 1000] Val Loss: 2.1973 Val Acc: 0.3744
# [Step 1100] Val Loss: 2.1845 Val Acc: 0.3920
# [Step 1200] Val Loss: 2.1711 Val Acc: 0.4031
# [Step 1300] Val Loss: 2.1562 Val Acc: 0.4196
# [Step 1400] Val Loss: 2.1402 Val Acc: 0.4213
# [Step 1500] Val Loss: 2.1231 Val Acc: 0.4390
# [Step 1600] Val Loss: 2.1049 Val Acc: 0.4389
# [Step 1700] Val Loss: 2.0851 Val Acc: 0.4591
# [Step 1800] Val Loss: 2.0646 Val Acc: 0.4709
# Epoch [1/20]  Train Loss: 2.1941  Train Acc: 0.3383
# [Step 1900] Val Loss: 2.0423 Val Acc: 0.4920
# [Step 2000] Val Loss: 2.0183 Val Acc: 0.4995
# [Step 2100] Val Loss: 1.9935 Val Acc: 0.5179
# [Step 2200] Val Loss: 1.9671 Val Acc: 0.5303
# [Step 2300] Val Loss: 1.9388 Val Acc: 0.5276
# [Step 2400] Val Loss: 1.9081 Val Acc: 0.5279
# [Step 2500] Val Loss: 1.8764 Val Acc: 0.5222
# [Step 2600] Val Loss: 1.8434 Val Acc: 0.5248
# [Step 2700] Val Loss: 1.8091 Val Acc: 0.5196
# [Step 2800] Val Loss: 1.7745 Val Acc: 0.5452
# [Step 2900] Val Loss: 1.7389 Val Acc: 0.5409
# [Step 3000] Val Loss: 1.7037 Val Acc: 0.5498
# [Step 3100] Val Loss: 1.6676 Val Acc: 0.5508
# [Step 3200] Val Loss: 1.6321 Val Acc: 0.5630
# [Step 3300] Val Loss: 1.5970 Val Acc: 0.5823
# [Step 3400] Val Loss: 1.5625 Val Acc: 0.5873
# [Step 3500] Val Loss: 1.5290 Val Acc: 0.5869
# [Step 3600] Val Loss: 1.4972 Val Acc: 0.5983
# [Step 3700] Val Loss: 1.4662 Val Acc: 0.5974
# Epoch [2/20]  Train Loss: 1.7593  Train Acc: 0.5527
# [Step 3800] Val Loss: 1.4373 Val Acc: 0.5908
# [Step 3900] Val Loss: 1.4081 Val Acc: 0.5848
# [Step 4000] Val Loss: 1.3813 Val Acc: 0.6068
# [Step 4100] Val Loss: 1.3556 Val Acc: 0.6040
# [Step 4200] Val Loss: 1.3310 Val Acc: 0.6132
# [Step 4300] Val Loss: 1.3081 Val Acc: 0.6211
# [Step 4400] Val Loss: 1.2862 Val Acc: 0.6250
# [Step 4500] Val Loss: 1.2654 Val Acc: 0.6128
# [Step 4600] Val Loss: 1.2458 Val Acc: 0.6128
# [Step 4700] Val Loss: 1.2266 Val Acc: 0.6182
# [Step 4800] Val Loss: 1.2082 Val Acc: 0.6249
# [Step 4900] Val Loss: 1.1914 Val Acc: 0.6255
# [Step 5000] Val Loss: 1.1750 Val Acc: 0.6274
# [Step 5100] Val Loss: 1.1595 Val Acc: 0.6177
# [Step 5200] Val Loss: 1.1442 Val Acc: 0.6312
# [Step 5300] Val Loss: 1.1305 Val Acc: 0.6299
# [Step 5400] Val Loss: 1.1165 Val Acc: 0.6280
# [Step 5500] Val Loss: 1.1036 Val Acc: 0.6362
# [Step 5600] Val Loss: 1.0913 Val Acc: 0.6267
# Epoch [3/20]  Train Loss: 1.2345  Train Acc: 0.6268
# [Step 5700] Val Loss: 1.0790 Val Acc: 0.6339
# [Step 5800] Val Loss: 1.0671 Val Acc: 0.6387
# [Step 5900] Val Loss: 1.0567 Val Acc: 0.6373
# [Step 6000] Val Loss: 1.0457 Val Acc: 0.6421
# [Step 6100] Val Loss: 1.0352 Val Acc: 0.6400
# [Step 6200] Val Loss: 1.0255 Val Acc: 0.6451
# [Step 6300] Val Loss: 1.0167 Val Acc: 0.6475
# [Step 6400] Val Loss: 1.0072 Val Acc: 0.6440
# [Step 6500] Val Loss: 0.9976 Val Acc: 0.6500
# [Step 6600] Val Loss: 0.9896 Val Acc: 0.6506
# [Step 6700] Val Loss: 0.9817 Val Acc: 0.6525
# [Step 6800] Val Loss: 0.9739 Val Acc: 0.6534
# [Step 6900] Val Loss: 0.9671 Val Acc: 0.6523
# [Step 7000] Val Loss: 0.9587 Val Acc: 0.6561
# [Step 7100] Val Loss: 0.9514 Val Acc: 0.6560
# [Step 7200] Val Loss: 0.9445 Val Acc: 0.6539
# [Step 7300] Val Loss: 0.9381 Val Acc: 0.6575
# [Step 7400] Val Loss: 0.9329 Val Acc: 0.6548
# [Step 7500] Val Loss: 0.9261 Val Acc: 0.6572
# Epoch [4/20]  Train Loss: 0.9856  Train Acc: 0.6590
# [Step 7600] Val Loss: 0.9210 Val Acc: 0.6638
# [Step 7700] Val Loss: 0.9134 Val Acc: 0.6645
# [Step 7800] Val Loss: 0.9083 Val Acc: 0.6649
# [Step 7900] Val Loss: 0.9039 Val Acc: 0.6665
# [Step 8000] Val Loss: 0.8987 Val Acc: 0.6678
# [Step 8100] Val Loss: 0.8936 Val Acc: 0.6599
# [Step 8200] Val Loss: 0.8869 Val Acc: 0.6686
# [Step 8300] Val Loss: 0.8827 Val Acc: 0.6673
# [Step 8400] Val Loss: 0.8775 Val Acc: 0.6735
# [Step 8500] Val Loss: 0.8754 Val Acc: 0.6722
# [Step 8600] Val Loss: 0.8698 Val Acc: 0.6768
# [Step 8700] Val Loss: 0.8659 Val Acc: 0.6687
# [Step 8800] Val Loss: 0.8603 Val Acc: 0.6741
# [Step 8900] Val Loss: 0.8562 Val Acc: 0.6822
# [Step 9000] Val Loss: 0.8535 Val Acc: 0.6854
# [Step 9100] Val Loss: 0.8491 Val Acc: 0.6808
# [Step 9200] Val Loss: 0.8456 Val Acc: 0.6808
# [Step 9300] Val Loss: 0.8408 Val Acc: 0.6858
# Epoch [5/20]  Train Loss: 0.8638  Train Acc: 0.6829
# [Step 9400] Val Loss: 0.8389 Val Acc: 0.6790
# [Step 9500] Val Loss: 0.8338 Val Acc: 0.6884
# [Step 9600] Val Loss: 0.8308 Val Acc: 0.6903
# [Step 9700] Val Loss: 0.8279 Val Acc: 0.6918
# [Step 9800] Val Loss: 0.8243 Val Acc: 0.6910
# [Step 9900] Val Loss: 0.8215 Val Acc: 0.6977
# [Step 10000] Val Loss: 0.8180 Val Acc: 0.6943
# [Step 10100] Val Loss: 0.8151 Val Acc: 0.6931
# [Step 10200] Val Loss: 0.8124 Val Acc: 0.6957
# [Step 10300] Val Loss: 0.8087 Val Acc: 0.6948
# [Step 10400] Val Loss: 0.8065 Val Acc: 0.7053
# [Step 10500] Val Loss: 0.8027 Val Acc: 0.6986
# [Step 10600] Val Loss: 0.8003 Val Acc: 0.6990
# [Step 10700] Val Loss: 0.7983 Val Acc: 0.7028
# [Step 10800] Val Loss: 0.7945 Val Acc: 0.7023
# [Step 10900] Val Loss: 0.7929 Val Acc: 0.7075
# [Step 11000] Val Loss: 0.7894 Val Acc: 0.7069
# [Step 11100] Val Loss: 0.7874 Val Acc: 0.7079
# [Step 11200] Val Loss: 0.7860 Val Acc: 0.7019
# Epoch [6/20]  Train Loss: 0.7930  Train Acc: 0.7049
# [Step 11300] Val Loss: 0.7824 Val Acc: 0.7090
# [Step 11400] Val Loss: 0.7799 Val Acc: 0.7068
# [Step 11500] Val Loss: 0.7779 Val Acc: 0.7095
# [Step 11600] Val Loss: 0.7752 Val Acc: 0.7145
# [Step 11700] Val Loss: 0.7742 Val Acc: 0.7182
# [Step 11800] Val Loss: 0.7738 Val Acc: 0.7162
# [Step 11900] Val Loss: 0.7701 Val Acc: 0.7154
# [Step 12000] Val Loss: 0.7665 Val Acc: 0.7167
# [Step 12100] Val Loss: 0.7655 Val Acc: 0.7139
# [Step 12200] Val Loss: 0.7631 Val Acc: 0.7163
# [Step 12300] Val Loss: 0.7602 Val Acc: 0.7177
# [Step 12400] Val Loss: 0.7583 Val Acc: 0.7209
# [Step 12500] Val Loss: 0.7572 Val Acc: 0.7224
# [Step 12600] Val Loss: 0.7540 Val Acc: 0.7227
# [Step 12700] Val Loss: 0.7515 Val Acc: 0.7235
# [Step 12800] Val Loss: 0.7507 Val Acc: 0.7274
# [Step 12900] Val Loss: 0.7480 Val Acc: 0.7251
# [Step 13000] Val Loss: 0.7476 Val Acc: 0.7215
# [Step 13100] Val Loss: 0.7436 Val Acc: 0.7263
# Epoch [7/20]  Train Loss: 0.7454  Train Acc: 0.7262
# [Step 13200] Val Loss: 0.7422 Val Acc: 0.7242
# [Step 13300] Val Loss: 0.7410 Val Acc: 0.7276
# [Step 13400] Val Loss: 0.7391 Val Acc: 0.7238
# [Step 13500] Val Loss: 0.7377 Val Acc: 0.7272
# [Step 13600] Val Loss: 0.7369 Val Acc: 0.7292
# [Step 13700] Val Loss: 0.7342 Val Acc: 0.7281
# [Step 13800] Val Loss: 0.7314 Val Acc: 0.7335
# [Step 13900] Val Loss: 0.7294 Val Acc: 0.7357
# [Step 14000] Val Loss: 0.7277 Val Acc: 0.7366
# [Step 14100] Val Loss: 0.7260 Val Acc: 0.7357
# [Step 14200] Val Loss: 0.7249 Val Acc: 0.7378
# [Step 14300] Val Loss: 0.7235 Val Acc: 0.7372
# [Step 14400] Val Loss: 0.7222 Val Acc: 0.7362
# [Step 14500] Val Loss: 0.7203 Val Acc: 0.7385
# [Step 14600] Val Loss: 0.7195 Val Acc: 0.7438
# [Step 14700] Val Loss: 0.7160 Val Acc: 0.7423
# [Step 14800] Val Loss: 0.7161 Val Acc: 0.7460
# [Step 14900] Val Loss: 0.7130 Val Acc: 0.7427
# [Step 15000] Val Loss: 0.7113 Val Acc: 0.7427
# Epoch [8/20]  Train Loss: 0.7091  Train Acc: 0.7462
# [Step 15100] Val Loss: 0.7093 Val Acc: 0.7456
# [Step 15200] Val Loss: 0.7092 Val Acc: 0.7399
# [Step 15300] Val Loss: 0.7075 Val Acc: 0.7446
# [Step 15400] Val Loss: 0.7082 Val Acc: 0.7444
# [Step 15500] Val Loss: 0.7039 Val Acc: 0.7498
# [Step 15600] Val Loss: 0.7021 Val Acc: 0.7497
# [Step 15700] Val Loss: 0.7007 Val Acc: 0.7474
# [Step 15800] Val Loss: 0.7001 Val Acc: 0.7481
# [Step 15900] Val Loss: 0.6997 Val Acc: 0.7513
# [Step 16000] Val Loss: 0.6995 Val Acc: 0.7528
# [Step 16100] Val Loss: 0.6954 Val Acc: 0.7525
# [Step 16200] Val Loss: 0.6938 Val Acc: 0.7488
# [Step 16300] Val Loss: 0.6928 Val Acc: 0.7530
# [Step 16400] Val Loss: 0.6905 Val Acc: 0.7506
# [Step 16500] Val Loss: 0.6895 Val Acc: 0.7548
# [Step 16600] Val Loss: 0.6887 Val Acc: 0.7548
# [Step 16700] Val Loss: 0.6872 Val Acc: 0.7585
# [Step 16800] Val Loss: 0.6869 Val Acc: 0.7583
# Epoch [9/20]  Train Loss: 0.6787  Train Acc: 0.7603
# [Step 16900] Val Loss: 0.6845 Val Acc: 0.7557
# [Step 17000] Val Loss: 0.6834 Val Acc: 0.7574
# [Step 17100] Val Loss: 0.6823 Val Acc: 0.7556
# [Step 17200] Val Loss: 0.6814 Val Acc: 0.7603
# [Step 17300] Val Loss: 0.6792 Val Acc: 0.7620
# [Step 17400] Val Loss: 0.6778 Val Acc: 0.7613
# [Step 17500] Val Loss: 0.6755 Val Acc: 0.7634
# [Step 17600] Val Loss: 0.6762 Val Acc: 0.7611
# [Step 17700] Val Loss: 0.6737 Val Acc: 0.7626
# [Step 17800] Val Loss: 0.6724 Val Acc: 0.7641
# [Step 17900] Val Loss: 0.6713 Val Acc: 0.7617
# [Step 18000] Val Loss: 0.6699 Val Acc: 0.7648
# [Step 18100] Val Loss: 0.6685 Val Acc: 0.7658
# [Step 18200] Val Loss: 0.6671 Val Acc: 0.7660
# [Step 18300] Val Loss: 0.6663 Val Acc: 0.7633
# [Step 18400] Val Loss: 0.6666 Val Acc: 0.7666
# [Step 18500] Val Loss: 0.6639 Val Acc: 0.7679
# [Step 18600] Val Loss: 0.6640 Val Acc: 0.7685
# [Step 18700] Val Loss: 0.6605 Val Acc: 0.7706
# Epoch [10/20]  Train Loss: 0.6526  Train Acc: 0.7724
# [Step 18800] Val Loss: 0.6595 Val Acc: 0.7690
# [Step 18900] Val Loss: 0.6598 Val Acc: 0.7693
# [Step 19000] Val Loss: 0.6587 Val Acc: 0.7662
# [Step 19100] Val Loss: 0.6557 Val Acc: 0.7703
# [Step 19200] Val Loss: 0.6553 Val Acc: 0.7723
# [Step 19300] Val Loss: 0.6564 Val Acc: 0.7700
# [Step 19400] Val Loss: 0.6528 Val Acc: 0.7733
# [Step 19500] Val Loss: 0.6534 Val Acc: 0.7719
# [Step 19600] Val Loss: 0.6512 Val Acc: 0.7728
# [Step 19700] Val Loss: 0.6495 Val Acc: 0.7747
# [Step 19800] Val Loss: 0.6513 Val Acc: 0.7712
# [Step 19900] Val Loss: 0.6469 Val Acc: 0.7734
# [Step 20000] Val Loss: 0.6475 Val Acc: 0.7757
# [Step 20100] Val Loss: 0.6460 Val Acc: 0.7769
# [Step 20200] Val Loss: 0.6452 Val Acc: 0.7770
# [Step 20300] Val Loss: 0.6426 Val Acc: 0.7762
# [Step 20400] Val Loss: 0.6423 Val Acc: 0.7776
# [Step 20500] Val Loss: 0.6411 Val Acc: 0.7780
# [Step 20600] Val Loss: 0.6402 Val Acc: 0.7772
# Epoch [11/20]  Train Loss: 0.6298  Train Acc: 0.7826
# [Step 20700] Val Loss: 0.6394 Val Acc: 0.7784
# [Step 20800] Val Loss: 0.6385 Val Acc: 0.7771
# [Step 20900] Val Loss: 0.6381 Val Acc: 0.7778
# [Step 21000] Val Loss: 0.6366 Val Acc: 0.7776
# [Step 21100] Val Loss: 0.6352 Val Acc: 0.7784
# [Step 21200] Val Loss: 0.6343 Val Acc: 0.7780
# [Step 21300] Val Loss: 0.6335 Val Acc: 0.7786
# [Step 21400] Val Loss: 0.6326 Val Acc: 0.7809
# [Step 21500] Val Loss: 0.6313 Val Acc: 0.7800
# [Step 21600] Val Loss: 0.6310 Val Acc: 0.7814
# [Step 21700] Val Loss: 0.6298 Val Acc: 0.7796
# [Step 21800] Val Loss: 0.6280 Val Acc: 0.7801
# [Step 21900] Val Loss: 0.6273 Val Acc: 0.7825
# [Step 22000] Val Loss: 0.6264 Val Acc: 0.7817
# [Step 22100] Val Loss: 0.6282 Val Acc: 0.7826
# [Step 22200] Val Loss: 0.6249 Val Acc: 0.7811
# [Step 22300] Val Loss: 0.6242 Val Acc: 0.7824
# [Step 22400] Val Loss: 0.6228 Val Acc: 0.7826
# [Step 22500] Val Loss: 0.6216 Val Acc: 0.7827
# Epoch [12/20]  Train Loss: 0.6099  Train Acc: 0.7905
# [Step 22600] Val Loss: 0.6212 Val Acc: 0.7829
# [Step 22700] Val Loss: 0.6204 Val Acc: 0.7846
# [Step 22800] Val Loss: 0.6211 Val Acc: 0.7818
# [Step 22900] Val Loss: 0.6196 Val Acc: 0.7859
# [Step 23000] Val Loss: 0.6179 Val Acc: 0.7867
# [Step 23100] Val Loss: 0.6191 Val Acc: 0.7823
# [Step 23200] Val Loss: 0.6158 Val Acc: 0.7850
# [Step 23300] Val Loss: 0.6153 Val Acc: 0.7853
# [Step 23400] Val Loss: 0.6177 Val Acc: 0.7819
# [Step 23500] Val Loss: 0.6138 Val Acc: 0.7860
# [Step 23600] Val Loss: 0.6124 Val Acc: 0.7867
# [Step 23700] Val Loss: 0.6129 Val Acc: 0.7852
# [Step 23800] Val Loss: 0.6106 Val Acc: 0.7865
# [Step 23900] Val Loss: 0.6100 Val Acc: 0.7866
# [Step 24000] Val Loss: 0.6096 Val Acc: 0.7878
# [Step 24100] Val Loss: 0.6094 Val Acc: 0.7850
# [Step 24200] Val Loss: 0.6095 Val Acc: 0.7904
# [Step 24300] Val Loss: 0.6064 Val Acc: 0.7888
# Epoch [13/20]  Train Loss: 0.5923  Train Acc: 0.7974
# [Step 24400] Val Loss: 0.6057 Val Acc: 0.7878
# [Step 24500] Val Loss: 0.6046 Val Acc: 0.7873
# [Step 24600] Val Loss: 0.6046 Val Acc: 0.7884
# [Step 24700] Val Loss: 0.6055 Val Acc: 0.7870
# [Step 24800] Val Loss: 0.6032 Val Acc: 0.7899
# [Step 24900] Val Loss: 0.6021 Val Acc: 0.7908
# [Step 25000] Val Loss: 0.6010 Val Acc: 0.7911
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1472138688.py in <cell line: 0>()
#      14
#      15 # 开始训练
# ---> 16 trainer_normalize.train(num_epochs)
#
# /content/wangdao_train.py in train(self, num_epochs)
#      99                 # eval_step的整数倍时进行一次验证集计算
#     100                 if self.eval_step is not None and self.eval_step > 0 and global_step % self.eval_step == 0:
# --> 101                     val_loss, val_acc = self.evaluate_once()
#     102                     self.val_loss_history.append(val_loss)
#     103                     self.val_acc_history.append(val_acc)
#
# /content/wangdao_train.py in evaluate_once(self)
#     249         total = 0
#     250         with torch.no_grad():
# --> 251             for batch in self.val_loader:
#     252                 inputs, targets = batch
#     253                 inputs = inputs.to(self.device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1468                 # no valid `self._rcvd_idx` is found (i.e., didn't break)
#    1469                 if not self._persistent_workers:
# -> 1470                     self._shutdown_workers()
#    1471                 raise StopIteration
#    1472
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _shutdown_workers(self)
#    1616                     # wrong, we set a timeout and if the workers fail to join,
#    1617                     # they are killed in the `finally` block.
# -> 1618                     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#    1619                 for q in self._index_queues:
#    1620                     q.cancel_join_thread()
#
# /usr/lib/python3.12/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# /usr/lib/python3.12/multiprocessing/popen_fork.py in wait(self, timeout)
#      38             if timeout is not None:
#      39                 from multiprocessing.connection import wait
# ---> 40                 if not wait([self.sentinel], timeout):
#      41                     return None
#      42             # This shouldn't block if wait() returned successfully.
#
# /usr/lib/python3.12/multiprocessing/connection.py in wait(object_list, timeout)
#    1134
#    1135             while True:
# -> 1136                 ready = selector.select(timeout)
#    1137                 if ready:
#    1138                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
trainer_normalize.plot_curves()
