# %% [markdown]
# 最好使用V100的高RAM配置

# %%
# !git clone https://github.com/THUDM/ChatGLM3
# Out:
# Cloning into 'ChatGLM3'...
# remote: Enumerating objects: 1559, done.
# remote: Counting objects: 100% (665/665), done.
# remote: Compressing objects: 100% (132/132), done.
# remote: Total 1559 (delta 573), reused 533 (delta 533), pack-reused 894 (from 2)
# Receiving objects: 100% (1559/1559), 17.75 MiB | 16.74 MiB/s, done.
# Resolving deltas: 100% (897/897), done.

# %%
# !ls
# Out:
# ChatGLM3  sample_data

# %%
# %cd ChatGLM3
# !cat requirements.txt
# !pip install -r requirements.txt
# Out:
# /content/ChatGLM3
# # basic requirements
#
# transformers==4.40.0
# cpm_kernels>=1.0.11
# torch>=2.3.0
# vllm>=0.4.2
# gradio>=4.26.0
# sentencepiece>=0.2.0
# sentence_transformers>=2.7.0
# accelerate>=0.29.2
# streamlit>=1.33.0
# fastapi>=0.110.0
# loguru~=0.7.2
# mdtex2html>=1.3.0
# latex2mathml>=3.77.0
# jupyter_client>=8.6.1
#
# # for openai demo
# openai>=1.30.1
# pydantic>=2.7.1
# sse-starlette>=2.1.0
# uvicorn>=0.29.0
# timm>=0.9.16
# tiktoken>=0.6.0
#
# # for langchain demo
#
# langchain>=0.2.1
# langchain_community>=0.2.0
# langchainhub>=0.1.15
# arxiv>=2.1.0

# %%
# !pip install transformers==4.39.3

from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm3-6b", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm3-6b", trust_remote_code=True, device='cuda')
model = model.eval()
# Out:
# Collecting transformers==4.39.3
#   Downloading transformers-4.39.3-py3-none-any.whl.metadata (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.39.3)
#   Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.39.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.39.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.39.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.39.3) (2025.7.14)
# Downloading transformers-4.39.3-py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 113.8 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 60.1 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.2
#     Uninstalling tokenizers-0.21.2:
#       Successfully uninstalled tokenizers-0.21.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.53.2
#     Uninstalling transformers-4.53.2:
#       Successfully uninstalled transformers-4.53.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.39.3 which is incompatible.
# Successfully installed tokenizers-0.15.2 transformers-4.39.3
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenization_chatglm.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - tokenization_chatglm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer.model:   0%|          | 0.00/1.02M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.00 [00:00<?, ?B/s]
# WARNING:transformers_modules.THUDM.chatglm3-6b.e9e0406d062cdb887444fe5bd546833920abd4ac.tokenization_chatglm:Setting eos_token is not supported, use the default one.
# WARNING:transformers_modules.THUDM.chatglm3-6b.e9e0406d062cdb887444fe5bd546833920abd4ac.tokenization_chatglm:Setting pad_token is not supported, use the default one.
# WARNING:transformers_modules.THUDM.chatglm3-6b.e9e0406d062cdb887444fe5bd546833920abd4ac.tokenization_chatglm:Setting unk_token is not supported, use the default one.
# config.json: 0.00B [00:00, ?B/s]
# configuration_chatglm.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - configuration_chatglm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_chatglm.py: 0.00B [00:00, ?B/s]
# quantization.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - quantization.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - modeling_chatglm.py
# - quantization.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/7 [00:00<?, ?it/s]
# model-00001-of-00007.safetensors:   0%|          | 0.00/1.83G [00:00<?, ?B/s]
# model-00002-of-00007.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00003-of-00007.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00004-of-00007.safetensors:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# model-00005-of-00007.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00006-of-00007.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00007-of-00007.safetensors:   0%|          | 0.00/1.05G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
model
# Out:
# ChatGLMForConditionalGeneration(
#   (transformer): ChatGLMModel(
#     (embedding): Embedding(
#       (word_embeddings): Embedding(65024, 4096)
#     )
#     (rotary_pos_emb): RotaryEmbedding()
#     (encoder): GLMTransformer(
#       (layers): ModuleList(
#         (0-27): 28 x GLMBlock(
#           (input_layernorm): RMSNorm()
#           (self_attention): SelfAttention(
#             (query_key_value): Linear(in_features=4096, out_features=4608, bias=True)
#             (core_attention): CoreAttention(
#               (attention_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (dense): Linear(in_features=4096, out_features=4096, bias=False)
#           )
#           (post_attention_layernorm): RMSNorm()
#           (mlp): MLP(
#             (dense_h_to_4h): Linear(in_features=4096, out_features=27392, bias=False)
#             (dense_4h_to_h): Linear(in_features=13696, out_features=4096, bias=False)
#           )
#         )
#       )
#       (final_layernorm): RMSNorm()
#     )
#     (output_layer): Linear(in_features=4096, out_features=65024, bias=False)
#   )
# )

# %%
import numpy as np
for idx, (key, value) in enumerate(model.named_parameters()):
    print(f"{key:^40} paramerters num:  {value.shape}")
# Out:
# transformer.embedding.word_embeddings.weight paramerters num:  torch.Size([65024, 4096])
# transformer.encoder.layers.0.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.0.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.0.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.0.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.0.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.0.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.0.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.1.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.1.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.1.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.1.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.1.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.1.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.1.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.2.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.2.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.2.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.2.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.2.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.2.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.2.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.3.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.3.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.3.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.3.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.3.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.3.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.3.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.4.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.4.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.4.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.4.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.4.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.4.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.4.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.5.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.5.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.5.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.5.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.5.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.5.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.5.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.6.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.6.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.6.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.6.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.6.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.6.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.6.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.7.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.7.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.7.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.7.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.7.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.7.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.7.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.8.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.8.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.8.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.8.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.8.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.8.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.8.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.9.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.9.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.9.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.9.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.9.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.9.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.9.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.10.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.10.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.10.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.10.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.10.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.10.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.10.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.11.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.11.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.11.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.11.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.11.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.11.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.11.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.12.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.12.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.12.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.12.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.12.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.12.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.12.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.13.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.13.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.13.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.13.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.13.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.13.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.13.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.14.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.14.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.14.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.14.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.14.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.14.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.14.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.15.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.15.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.15.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.15.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.15.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.15.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.15.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.16.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.16.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.16.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.16.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.16.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.16.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.16.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.17.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.17.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.17.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.17.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.17.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.17.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.17.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.18.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.18.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.18.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.18.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.18.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.18.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.18.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.19.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.19.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.19.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.19.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.19.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.19.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.19.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.20.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.20.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.20.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.20.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.20.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.20.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.20.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.21.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.21.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.21.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.21.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.21.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.21.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.21.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.22.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.22.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.22.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.22.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.22.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.22.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.22.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.23.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.23.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.23.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.23.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.23.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.23.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.23.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.24.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.24.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.24.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.24.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.24.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.24.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.24.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.25.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.25.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.25.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.25.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.25.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.25.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.25.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.26.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.26.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.26.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.26.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.26.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.26.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.26.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.layers.27.input_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.27.self_attention.query_key_value.weight paramerters num:  torch.Size([4608, 4096])
# transformer.encoder.layers.27.self_attention.query_key_value.bias paramerters num:  torch.Size([4608])
# transformer.encoder.layers.27.self_attention.dense.weight paramerters num:  torch.Size([4096, 4096])
# transformer.encoder.layers.27.post_attention_layernorm.weight paramerters num:  torch.Size([4096])
# transformer.encoder.layers.27.mlp.dense_h_to_4h.weight paramerters num:  torch.Size([27392, 4096])
# transformer.encoder.layers.27.mlp.dense_4h_to_h.weight paramerters num:  torch.Size([4096, 13696])
# transformer.encoder.final_layernorm.weight paramerters num:  torch.Size([4096])
#     transformer.output_layer.weight      paramerters num:  torch.Size([65024, 4096])

# %%
# data=input("请输入:")
response,history = model.chat(tokenizer, 'AI太难学怎么办', history=[])
print(response)
# Out:
# 学习AI（人工智能）可能会有一定的难度，但是请不要气馁。以下是一些建议，可以帮助你更好地学习和理解AI：
#
# 1. 基础知识：确保你具备一定的数学和编程基础，这将有助于你更好地理解AI的概念。
#
# 2. 学习资源：利用网络资源，如在线课程、博客、书籍等，来学习AI基础知识。有很多优秀的资源可以帮助你入门，例如：吴恩达的《深度学习专项课程》、李飞飞等的《CS231n：卷积神经网络与视觉识别》等。
#
# 3. 实践：实践是巩固理论知识的最好方法。通过实际项目或编程挑战，将所学知识应用到实际问题中。这将帮助你更好地理解AI算法的工作原理和实际应用。
#
# 4. 建立自己的项目：从简单的项目开始，如图像分类、文本分类等，逐步提高难度。这将帮助你将所学知识应用于实际问题，并培养你的动手能力。
#
# 5. 交流与讨论：加入AI相关的社区和讨论组，与他人分享和讨论学习经验。这将有助于你发现自己的不足之处，并从他人的经验中获益。
#
# 6. 持续学习：AI领域发展迅速，不断有新的理论和技术涌现。保持对AI的热情，持续学习，跟上领域的发展趋势。
#
# 最后，学习AI需要时间和耐心。不要气馁，坚持下去，相信你一定能够掌握AI技能并取得成功。祝你学习顺利！

# %%
#挂载谷歌云盘
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#查看huggingface下载的模型，并复制到谷歌云盘里
import os
# os.listdir('/root/.cache/huggingface/hub/models--THUDM--chatglm3-6b')
# #os.cp 上面路径内容到 /content/drive/下面
# os.system('cp -r /root/.cache/huggingface/hub/models--THUDM--chatglm3-6b /content/drive/MyDrive/')
