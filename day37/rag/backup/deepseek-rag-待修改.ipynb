# %%
import requests
import json

# DeepSeek API 的端点（假设的，具体以官方文档为准）
DEEPSEEK_API_URL = "https://api.deepseek.com"

# 你的 API 密钥（替换为你的实际密钥）
API_KEY = "sk-8d043c487cf04418bbdcf659f052331e"

# 请求头，包含认证信息
headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}

# 定义 RAG 请求的输入
def rag_query(question, context=None):
    # 构造请求体
    payload = {
        "question": question,
        "context": context  # 可选的上下文信息
    }

    # 发送 POST 请求到 DeepSeek API
    response = requests.post(DEEPSEEK_API_URL, headers=headers, data=json.dumps(payload))

    # 检查响应状态
    if response.status_code == 200:
        # 解析返回的 JSON 数据
        result = response.json()
        return result
    else:
        print(f"Error: {response.status_code}, {response.text}")
        return None

# 示例问题
question = "How old was he when he died?"
context=open("davinci.txt", "r", encoding="utf-8").read()
# 调用 RAG 查询
response = rag_query(question,context)

# 输出结果
if response:
    print("答案:", response.get("answer"))
    print("相关文档:", response.get("documents"))
else:
    print("请求失败")
# Out:
# Error: 404, {
#   "event_id": "30-inst-175-20250305194308-357f0cb3",
#   "error_msg": "Not Found. Please check the configuration."
# }
#
# 请求失败

# %%
question = "my question is How old was he when he died?"
context=open("davinci.txt", "r", encoding="utf-8").read()

# %%
# pip3 install langchain_openai
# python3 deepseek_langchain.py
from langchain_openai.chat_models.base import BaseChatOpenAI

llm = BaseChatOpenAI(
    model='deepseek-chat', 
    openai_api_key='sk-8d043c487cf04418bbdcf659f052331e',
    openai_api_base='https://api.deepseek.com',
    max_tokens=1024
)

response = llm.invoke(context+question)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[2], line 12
#       3 from langchain_openai.chat_models.base import BaseChatOpenAI
#       5 llm = BaseChatOpenAI(
#       6     model='deepseek-chat',
#       7     openai_api_key='sk-8d043c487cf04418bbdcf659f052331e',
#       8     openai_api_base='https://api.deepseek.com',
#       9     max_tokens=1024
#      10 )
# ---> 12 response = llm.invoke(context+question)
#      13 print(response.content)
#
# File C:\Program Files\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# ...
